# %% [markdown]
# # A simple test for inquiry model
#
#
# Here is the setting:
#
# - My thought: Yintai Ma [09:23]
#   - Suppose I have a video X of 100 frames, denoting as X[0] to X[99]. We then split it to multiple clips without overlap. If then length of each clip is 5 frames, then we come up with a sequences of clips X[0:5],X[5:10],...,X[95:100]. We use the encoder to transfer the sequences of clips to sequences of embeddeds, reads y[0],y[1],...,y[20]. Now we randomly pick some frames from X as validation clip and transfer it into validation embedded y_hat. We want to see how y_hat is matching to the sequences of y[0]...y[20].
#
# - Diego:
#   - You have video X. Randomly pick  sequences of frames (non overlapping). Say x[4:10], x[34:37],x[85:95]. Now concatenate them into a single video. This is now your query. From here, create embedding sequence y[0],…y[K]. Now do DTW of y against your encoded sequences of the videos in the database.
#   - This is subject to experimentation. I agree that there should be overlap. Overlap by half.
#
# - My thought: There are many variations for the implementation:
#   1. we keep overlaps for y. We transfer X[0:5],X[1:6],....X[94:99],X[95:100] into y[0]...y[100]. Now we want to see how y_hat is matching to y[].
#   2. When we pick some frames from X to composite validation clips, do we always pick 5 consecutive frames? Should we ever transfer X[0]+X[2:6] into y_hat?
#   3. How we match y_hat to y[] if y_hat is also a sequences? I think this is where DTW comes in right? If y_hat is just one embedded, then what we need is basically a simple comparison between the distance of two embedded. However, if y_hat is a sequences, say it has y_hat[0] and y_hat[1], then we will need to use DTW to consider the case where both y_hat[0] matches to y[0] and y_hat[1] matches to y[3] are the best query retrieve.

# %%
import sys,os,os.path
sys.path.append(os.path.expanduser('/home/lab.analytics.northwestern.edu/yma/git/videodl/seq_inquiry'))
os.environ['CUDA_VISIBLE_DEVICES']='2'

# %%
from keras.models import Sequential, Model
from keras.utils import plot_model
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, LSTM, RepeatVector
from keras.layers.wrappers import *
from keras.layers.core import *
from keras.layers.convolutional import Conv3D
from keras.layers.convolutional_recurrent import ConvLSTM2D
from keras.layers.normalization import BatchNormalization
from keras.callbacks import TensorBoard
from keras.optimizers import RMSprop
from keras import backend as K

import csv
import os
import time
import sys
import numpy as np
import matplotlib
# matplotlib.use('Agg')
import pylab as plt
# from scipy.misc import toimage

import imageio
import cv2
import numpy as np
import numpngw
import pandas as pd 

from IPython.display import HTML
import random
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Test Data Generation Function

# %%
GENERATE_DATA = 1 
LOG_DIR = "../../tensorboard/log/"
EPOCH = 150
sequenceLength = 3
setup_name = "clrmvsq_simple_vgg_a"
N_SAMPLES = 1000
BATCHSIZE = 5
ucf_generate_fps = 2  # The fps to sample from the original UCF data to generate the train and val set
data_path = "../../data/UCF/"

batch_size=20
data_type = 'images'
concat=False

# %%
import data_seq
# from importlib import reload
data_seq = reload(data_seq)

data = data_seq.DataSet(seq_length=5,class_limit=10)

print (data.data[:1], '\n')
print (data.classes[:5])
print (data.image_shape)
# Out:
# ([['train', 'ApplyEyeMakeup', 'v_ApplyEyeMakeup_g08_c02', '118']], '\n')
# ['ApplyEyeMakeup', 'ApplyLipstick', 'Archery', 'BabyCrawling', 'BalanceBeam']
# (224, 224, 3)

# %%
generator = data.seq_generator(batch_size, 'train', 'images')

X,y  = next(generator);

print(X.shape)

images = X[18]
imageio.mimsave('./movie.gif', images)
HTML('<img src="./movie.gif">')
# Out:
# Show 'data' shape:
# 944
# Show 'data' first element:
# ['train', 'ApplyEyeMakeup', 'v_ApplyEyeMakeup_g08_c02', '118']
# Creating train generator with 944 videos.
# Recommended steps per epoch = videos/batch_size
# (128, 12, 5)
# (175, 12, 5)
# (73, 12, 5)
# (97, 12, 5)
# (116, 12, 5)
# (58, 12, 5)
# (243, 12, 5)
# (142, 12, 5)
# (100, 12, 5)
# (111, 12, 5)
# (193, 12, 5)
# (101, 12, 5)
# (185, 12, 5)
# (141, 12, 5)
# (212, 12, 5)
# (85, 12, 5)
# (104, 12, 5)
# (185, 12, 5)
# (80, 12, 5)
# (45, 12, 5)
# (20, 5, 224, 224, 3)
# /home/lab.analytics.northwestern.edu/yma/.conda/envs/dl/lib/python2.7/site-packages/imageio/core/util.py:78: UserWarning: Lossy conversion from float32 to uint8, range [0, 1]
#   dtype_str, out_type.__name__))
# <img src="./movie.gif">

# %%
# X,y  = next(generator);
# for i in range (0,5):
#     images = X[i][0]
#     plt.imshow(images)
#     plt.show()

# %%
for _ in range(10):
    X,y  = next(generator);
# Out:
# (53, 12, 5)
# (242, 12, 5)
# (93, 12, 5)
# (206, 12, 5)
# (91, 12, 5)
# (100, 12, 5)
# (66, 12, 5)
# (104, 12, 5)
# (100, 12, 5)
# (209, 12, 5)
# (228, 12, 5)
# (51, 12, 5)
# (75, 12, 5)
# (196, 12, 5)
# (135, 12, 5)
# (173, 12, 5)
# (155, 12, 5)
# (181, 12, 5)
# (179, 12, 5)
# (95, 12, 5)
# (300, 12, 5)
# (103, 12, 5)
# (176, 12, 5)
# (116, 12, 5)
# (68, 12, 5)
# (56, 12, 5)
# (61, 12, 5)
# (65, 12, 5)
# (65, 12, 5)
# (67, 12, 5)
# (166, 12, 5)
# (135, 12, 5)
# (111, 12, 5)
# (87, 12, 5)
# (68, 12, 5)
# (175, 12, 5)
# (186, 12, 5)
# (93, 12, 5)
# (233, 12, 5)
# (107, 12, 5)
# (259, 12, 5)
# (130, 12, 5)
# (161, 12, 5)
# (118, 12, 5)
# (128, 12, 5)
# (151, 12, 5)
# (158, 12, 5)
# (64, 12, 5)
# (88, 12, 5)
# (128, 12, 5)
# (81, 12, 5)
# (264, 12, 5)
# (166, 12, 5)
# (159, 12, 5)
# (114, 12, 5)
# (104, 12, 5)
# (114, 12, 5)
# (179, 12, 5)
# (68, 12, 5)
# (100, 12, 5)
# (106, 12, 5)
# (186, 12, 5)
# (127, 12, 5)
# (244, 12, 5)
# (198, 12, 5)
# (97, 12, 5)
# (195, 12, 5)
# (101, 12, 5)
# (96, 12, 5)
# (262, 12, 5)
# (250, 12, 5)
# (126, 12, 5)
# (221, 12, 5)
# (116, 12, 5)
# (100, 12, 5)
# (128, 12, 5)
# (110, 12, 5)
# (126, 12, 5)
# (88, 12, 5)
# (117, 12, 5)
# (125, 12, 5)
# (185, 12, 5)
# (75, 12, 5)
# (168, 12, 5)
# (110, 12, 5)
# (107, 12, 5)
# (104, 12, 5)
# (92, 12, 5)
# (126, 12, 5)
# (116, 12, 5)
# (120, 12, 5)
# (79, 12, 5)
# (153, 12, 5)
# (263, 12, 5)
# (201, 12, 5)
# (108, 12, 5)
# (111, 12, 5)
# (72, 12, 5)
# (132, 12, 5)
# (152, 12, 5)
# (51, 12, 5)
# (70, 12, 5)
# (161, 12, 5)
# (166, 12, 5)
# (157, 12, 5)
# (176, 12, 5)
# (126, 12, 5)
# (116, 12, 5)
# (132, 12, 5)
# (108, 12, 5)
# (126, 12, 5)
# (126, 12, 5)
# (258, 12, 5)
# (183, 12, 5)
# (58, 12, 5)
# (132, 12, 5)
# (190, 12, 5)
# (183, 12, 5)
# (67, 12, 5)
# (99, 12, 5)
# (205, 12, 5)
# (150, 12, 5)
# (113, 12, 5)
# (170, 12, 5)
# (117, 12, 5)
# (99, 12, 5)
# (236, 12, 5)
# (114, 12, 5)
# (111, 12, 5)
# (201, 12, 5)
# (182, 12, 5)
# (68, 12, 5)
# (104, 12, 5)
# (94, 12, 5)
# (205, 12, 5)
# (47, 12, 5)
# (94, 12, 5)
# (242, 12, 5)
# (167, 12, 5)
# (223, 12, 5)
# (85, 12, 5)
# (104, 12, 5)
# (63, 12, 5)
# (100, 12, 5)
# (126, 12, 5)
# (245, 12, 5)
# (160, 12, 5)
# (285, 12, 5)
# (190, 12, 5)
# (132, 12, 5)
# (111, 12, 5)
# (204, 12, 5)
# (103, 12, 5)
# (88, 12, 5)
# (68, 12, 5)
# (104, 12, 5)
# (185, 12, 5)
# (111, 12, 5)
# (91, 12, 5)
# (189, 12, 5)
# (105, 12, 5)
# (101, 12, 5)
# (65, 12, 5)
# (105, 12, 5)
# (172, 12, 5)
# (112, 12, 5)
# (125, 12, 5)
# (92, 12, 5)
# (117, 12, 5)
# (143, 12, 5)
# (64, 12, 5)
# (125, 12, 5)
# (174, 12, 5)
# (148, 12, 5)
# (96, 12, 5)
# (77, 12, 5)
# (119, 12, 5)
# (85, 12, 5)
# (207, 12, 5)
# (95, 12, 5)
# (76, 12, 5)
# (240, 12, 5)
# (219, 12, 5)
# (68, 12, 5)
# (68, 12, 5)
# (243, 12, 5)
# (108, 12, 5)
# (74, 12, 5)
# (199, 12, 5)
# (126, 12, 5)
# (295, 12, 5)
# (148, 12, 5)
# (176, 12, 5)
# (45, 12, 5)
# (85, 12, 5)
# (127, 12, 5)
# (195, 12, 5)
# (300, 12, 5)
# (92, 12, 5)
# (105, 12, 5)

# %%
X,y  = next(generator);

print(X.shape)

images = X[18]
imageio.mimsave('./movie.gif', images)
HTML('<img src="./movie.gif">')
# Out:
# (296, 12, 5)
# (111, 12, 5)
# (126, 12, 5)
# (81, 12, 5)
# (213, 12, 5)
# (111, 12, 5)
# (102, 12, 5)
# (112, 12, 5)
# (104, 12, 5)
# (74, 12, 5)
# (95, 12, 5)
# (143, 12, 5)
# (146, 12, 5)
# (74, 12, 5)
# (175, 12, 5)
# (205, 12, 5)
# (170, 12, 5)
# (209, 12, 5)
# (116, 12, 5)
# (61, 12, 5)
# (20, 5, 224, 224, 3)
# <img src="./movie.gif">

# %% [markdown]
# # Must Run from here: Adjust the saved model

# %%
# Examaine model file
from keras.models import load_model

# weights_file = "/home/lab.analytics.northwestern.edu/yma/git/data/checkpoints/ucf_vgg16_seq3_convlstm.040-0.0857.hdf5"

weights_file = "/home/lab.analytics.northwestern.edu/yma/git/data/checkpoints/ucf_vgg16_simple_seq3_convlstm.001-0.03.hdf5"

model = load_model(weights_file)

# %%
json_string = model.to_json()

# %% [markdown]
# # Test Model Validation

# %%
print("--- Start Assembling the Model ---")

inputs = Input(shape=(sequenceLength,224,224,3))

# conved = TimeDistributed(Lambda(MyCNN), input_shape=(sequenceLength,40,40,1)) (inputs)

x = TimeDistributed(Conv2D(64, (3, 3), padding='same', activation='relu', name='block1_conv1'), input_shape=(sequenceLength,224,224,3))(inputs)
x = TimeDistributed(MaxPooling2D((2, 2), name='block1_pool'))(x)
# x = TimeDistributed(MaxPooling2D((2, 2)))(x)
x = TimeDistributed(Conv2D(128, (3, 3), padding='same', activation='relu', name='block2_conv1'))(x)
x = TimeDistributed(MaxPooling2D((2, 2), name='block2_pool'))(x)
x = TimeDistributed(Conv2D(256, (3, 3), padding='same', activation='relu', name='block3_conv1'))(x)
x = TimeDistributed(MaxPooling2D((2, 2), name='block3_pool'))(x)
x = TimeDistributed(Conv2D(512, (3, 3), padding='same', activation='relu', name='block4_conv1'))(x)
x = TimeDistributed(MaxPooling2D((2, 2), name='block4_pool'))(x)
x = TimeDistributed(Conv2D(512, (3, 3), padding='same', activation='relu', name='block5_conv1'))(x)

# LSTM part
x = TimeDistributed(MaxPooling2D((2, 2), name='block5_pool'))(x)
# x = TimeDistributed(Flatten())(x)

encoded = ConvLSTM2D(filters=100, kernel_size=(3, 3),padding='same', return_sequences=True)(x)

encoder = Model(output=encoded,input=inputs)
# myoptmizer = RMSprop(lr=0.1, decay=1e-4)
# autoencoder.compile(loss='mean_squared_error', optimizer=myoptmizer)
encoder.compile(loss='mean_squared_error', optimizer='RMSprop')

# plot_model(encoder, to_file='query_model.png', show_shapes=True)

print('--- Finish Compile and Plot Model ---')
# Out:
# --- Start Assembling the Model ---
# --- Finish Compile and Plot Model ---
# /home/lab.analytics.northwestern.edu/yma/.local/lib/python2.7/site-packages/ipykernel/__main__.py:24: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`

# %%
weights_file = "/home/lab.analytics.northwestern.edu/yma/git/data/checkpoints/ucf_simple_vgg16_seq3_convlstm_c5.002-0.0186.hdf5"
encoder.load_weights(weights_file, by_name=True)

# %% [markdown]
# ## Code Start from here

# %%
SEQ_LENGTH = 3
# the number of frames in each clip

N_database = 500

inq_length = 8
# the number of clips in the inquiry, no overlap

# %%
# Out:
# 2498

# %%
def create_database(data):
    database = []
    for i in range(0, N_database):
        smp = data.data[i]
        # ['train', 'BaseballPitch', 'v_BaseballPitch_g25_c06', '123']
        vid_len = int(smp[3])
        frams = data.get_frames_for_sample(smp)
# No need for this
#         frams = data.rescale_list(frams, vid_len-1)
        seq = data.build_image_sequence(frams)
        seq = np.array(seq)
        
        seqX = []
        print('Idx:',i,  smp[2], 'Length:' , len(seq)-SEQ_LENGTH,'Jump:', (SEQ_LENGTH>>1)+1 )
        for j in range(0,len(seq)-SEQ_LENGTH, (SEQ_LENGTH>>1)+1):
            seqX.append(seq[j:j+SEQ_LENGTH])
        seqX = np.array(seqX)
        seqY = encoder.predict(seqX)
        database.append((seqY, smp[2]))
    return database

# %%
import random
def get_inquiry(data, if_random=True, pos = 0):
    if if_random:
        smp = random.choice(data.data)
    else:
        smp = data.data[pos]
    
    vid_len = int(smp[3])
    frams = data.get_frames_for_sample(smp)
    frams = data.rescale_list(frams, vid_len-1)
    seq = data.build_image_sequence(frams)
    seq = np.array(seq)
    
    seqX = []
    X_frames_start= []
    stepsize = vid_len / inq_length - 2
    for j in range(0, inq_length):
        jst = j*stepsize
        jend = j*stepsize+SEQ_LENGTH
        seqX.append(seq[jst:jend])
        X_frames_start.append((jst, jend))
    seqX = np.array(seqX)
    seqY = encoder.predict(seqX)
    return (seqX, seqY ,smp[2], X_frames_start)

# %%
def inquiry_in_database(inquiry_seqY, database):
    scores= []
    score_names = []
    bestscore = 1<<30
#     dist, cost, acc, path
    for i in database:
#         print(inquiry_seqY.shape)
#         print(i[0].shape)
        seqyflat = inquiry_seqY.reshape((inquiry_seqY.shape[0], 3*7*7*100))
        iyflat = i[0].reshape((i[0].shape[0], 3*7*7*100))
#         print(seqyflat.shape)
#         print(iyflat.shape)
        dist, cost, acc, path = dtw(seqyflat, iyflat, dist=lambda x, y: np.linalg.norm(x - y, ord=1))
        scores.append((dist,i[1]))
        if dist< bestscore:
            bestscore = dist
            bestpath = path
            bestacc= acc
            bestfilename = i[1]
    scores = sorted(scores, key=lambda x:x[0])
    return (bestscore, bestacc, bestpath, bestfilename, scores)

# %%
import data_seq
from scipy.spatial.distance import euclidean
from dtw import dtw
# %pylab inline

data_seq = reload(data_seq)
data = data_seq.DataSet(seq_length=SEQ_LENGTH,class_limit=20, random_class=True)
random.shuffle(data.data)
print(len(data.data))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/lab.analytics.northwestern.edu/yma/.local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
database = create_database(data)
# Out:
# ('Idx:', 0, 'v_MilitaryParade_g23_c02', 'Length:', 122, 'Jump:', 2)
# ('Idx:', 1, 'v_BrushingTeeth_g04_c01', 'Length:', 190, 'Jump:', 2)
# ('Idx:', 2, 'v_CleanAndJerk_g16_c04', 'Length:', 103, 'Jump:', 2)
# ('Idx:', 3, 'v_CricketShot_g05_c07', 'Length:', 63, 'Jump:', 2)
# ('Idx:', 4, 'v_PlayingDhol_g24_c01', 'Length:', 264, 'Jump:', 2)
# ('Idx:', 5, 'v_PlayingDhol_g19_c04', 'Length:', 297, 'Jump:', 2)
# ('Idx:', 6, 'v_ApplyEyeMakeup_g14_c03', 'Length:', 235, 'Jump:', 2)
# ('Idx:', 7, 'v_BrushingTeeth_g06_c02', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 8, 'v_MilitaryParade_g20_c02', 'Length:', 147, 'Jump:', 2)
# ('Idx:', 9, 'v_BabyCrawling_g09_c04', 'Length:', 204, 'Jump:', 2)
# ('Idx:', 10, 'v_WallPushups_g20_c06', 'Length:', 86, 'Jump:', 2)
# ('Idx:', 11, 'v_ApplyEyeMakeup_g07_c04', 'Length:', 140, 'Jump:', 2)
# ('Idx:', 12, 'v_Surfing_g15_c02', 'Length:', 160, 'Jump:', 2)
# ('Idx:', 13, 'v_PlayingDhol_g22_c05', 'Length:', 251, 'Jump:', 2)
# ('Idx:', 14, 'v_MilitaryParade_g07_c05', 'Length:', 145, 'Jump:', 2)
# ('Idx:', 15, 'v_Shotput_g03_c05', 'Length:', 63, 'Jump:', 2)
# ('Idx:', 16, 'v_PushUps_g12_c03', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 17, 'v_BlowDryHair_g16_c04', 'Length:', 117, 'Jump:', 2)
# ('Idx:', 18, 'v_ApplyEyeMakeup_g19_c04', 'Length:', 129, 'Jump:', 2)
# ('Idx:', 19, 'v_Hammering_g08_c03', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 20, 'v_CleanAndJerk_g08_c01', 'Length:', 233, 'Jump:', 2)
# ('Idx:', 21, 'v_Surfing_g12_c06', 'Length:', 165, 'Jump:', 2)
# ('Idx:', 22, 'v_Kayaking_g20_c05', 'Length:', 160, 'Jump:', 2)
# ('Idx:', 23, 'v_IceDancing_g11_c04', 'Length:', 253, 'Jump:', 2)
# ('Idx:', 24, 'v_BabyCrawling_g17_c05', 'Length:', 107, 'Jump:', 2)
# ('Idx:', 25, 'v_Surfing_g01_c03', 'Length:', 217, 'Jump:', 2)
# ('Idx:', 26, 'v_ApplyEyeMakeup_g05_c06', 'Length:', 113, 'Jump:', 2)
# ('Idx:', 27, 'v_Hammering_g05_c01', 'Length:', 97, 'Jump:', 2)
# ('Idx:', 28, 'v_HighJump_g05_c02', 'Length:', 68, 'Jump:', 2)
# ('Idx:', 29, 'v_MilitaryParade_g16_c01', 'Length:', 96, 'Jump:', 2)
# ('Idx:', 30, 'v_PushUps_g02_c03', 'Length:', 76, 'Jump:', 2)
# ('Idx:', 31, 'v_PushUps_g18_c04', 'Length:', 68, 'Jump:', 2)
# ('Idx:', 32, 'v_PlayingGuitar_g23_c06', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 33, 'v_BabyCrawling_g24_c06', 'Length:', 178, 'Jump:', 2)
# ('Idx:', 34, 'v_Shotput_g13_c04', 'Length:', 72, 'Jump:', 2)
# ('Idx:', 35, 'v_CricketShot_g10_c03', 'Length:', 70, 'Jump:', 2)
# ('Idx:', 36, 'v_BabyCrawling_g14_c01', 'Length:', 120, 'Jump:', 2)
# ('Idx:', 37, 'v_Surfing_g10_c03', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 38, 'v_CleanAndJerk_g01_c01', 'Length:', 97, 'Jump:', 2)
# ('Idx:', 39, 'v_BrushingTeeth_g04_c04', 'Length:', 78, 'Jump:', 2)
# ('Idx:', 40, 'v_ApplyEyeMakeup_g07_c06', 'Length:', 160, 'Jump:', 2)
# ('Idx:', 41, 'v_PushUps_g04_c04', 'Length:', 127, 'Jump:', 2)
# ('Idx:', 42, 'v_WallPushups_g04_c01', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 43, 'v_MilitaryParade_g25_c03', 'Length:', 125, 'Jump:', 2)
# ('Idx:', 44, 'v_MilitaryParade_g11_c01', 'Length:', 108, 'Jump:', 2)
# ('Idx:', 45, 'v_PlayingGuitar_g08_c02', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 46, 'v_Hammering_g22_c06', 'Length:', 150, 'Jump:', 2)
# ('Idx:', 47, 'v_PlayingDaf_g10_c03', 'Length:', 287, 'Jump:', 2)
# ('Idx:', 48, 'v_PlayingDaf_g07_c05', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 49, 'v_BlowDryHair_g15_c01', 'Length:', 94, 'Jump:', 2)
# ('Idx:', 50, 'v_CleanAndJerk_g10_c04', 'Length:', 258, 'Jump:', 2)
# ('Idx:', 51, 'v_BrushingTeeth_g12_c04', 'Length:', 273, 'Jump:', 2)
# ('Idx:', 52, 'v_Hammering_g14_c01', 'Length:', 248, 'Jump:', 2)
# ('Idx:', 53, 'v_IceDancing_g03_c05', 'Length:', 241, 'Jump:', 2)
# ('Idx:', 54, 'v_PlayingDhol_g18_c03', 'Length:', 196, 'Jump:', 2)
# ('Idx:', 55, 'v_PushUps_g14_c01', 'Length:', 100, 'Jump:', 2)
# ('Idx:', 56, 'v_IceDancing_g15_c02', 'Length:', 248, 'Jump:', 2)
# ('Idx:', 57, 'v_PlayingPiano_g14_c03', 'Length:', 206, 'Jump:', 2)
# ('Idx:', 58, 'v_Surfing_g03_c04', 'Length:', 132, 'Jump:', 2)
# ('Idx:', 59, 'v_PlayingGuitar_g10_c02', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 60, 'v_Hammering_g10_c02', 'Length:', 74, 'Jump:', 2)
# ('Idx:', 61, 'v_IceDancing_g02_c05', 'Length:', 241, 'Jump:', 2)
# ('Idx:', 62, 'v_PushUps_g11_c03', 'Length:', 52, 'Jump:', 2)
# ('Idx:', 63, 'v_CricketShot_g14_c04', 'Length:', 133, 'Jump:', 2)
# ('Idx:', 64, 'v_BabyCrawling_g07_c01', 'Length:', 201, 'Jump:', 2)
# ('Idx:', 65, 'v_IceDancing_g12_c01', 'Length:', 237, 'Jump:', 2)
# ('Idx:', 66, 'v_WallPushups_g06_c02', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 67, 'v_Hammering_g16_c01', 'Length:', 66, 'Jump:', 2)
# ('Idx:', 68, 'v_Hammering_g17_c01', 'Length:', 148, 'Jump:', 2)
# ('Idx:', 69, 'v_Kayaking_g22_c02', 'Length:', 178, 'Jump:', 2)
# ('Idx:', 70, 'v_IceDancing_g07_c04', 'Length:', 227, 'Jump:', 2)
# ('Idx:', 71, 'v_MilitaryParade_g14_c04', 'Length:', 104, 'Jump:', 2)
# ('Idx:', 72, 'v_IceDancing_g04_c04', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 73, 'v_IceDancing_g23_c07', 'Length:', 244, 'Jump:', 2)
# ('Idx:', 74, 'v_BabyCrawling_g21_c02', 'Length:', 116, 'Jump:', 2)
# ('Idx:', 75, 'v_WallPushups_g17_c01', 'Length:', 122, 'Jump:', 2)
# ('Idx:', 76, 'v_IceDancing_g09_c04', 'Length:', 258, 'Jump:', 2)
# ('Idx:', 77, 'v_Surfing_g04_c01', 'Length:', 110, 'Jump:', 2)
# ('Idx:', 78, 'v_BabyCrawling_g20_c03', 'Length:', 261, 'Jump:', 2)
# ('Idx:', 79, 'v_Surfing_g10_c06', 'Length:', 189, 'Jump:', 2)
# ('Idx:', 80, 'v_PlayingDhol_g15_c01', 'Length:', 196, 'Jump:', 2)
# ('Idx:', 81, 'v_BabyCrawling_g19_c04', 'Length:', 142, 'Jump:', 2)
# ('Idx:', 82, 'v_BlowDryHair_g07_c07', 'Length:', 82, 'Jump:', 2)
# ('Idx:', 83, 'v_IceDancing_g16_c05', 'Length:', 239, 'Jump:', 2)
# ('Idx:', 84, 'v_Shotput_g25_c03', 'Length:', 84, 'Jump:', 2)
# ('Idx:', 85, 'v_HighJump_g08_c03', 'Length:', 120, 'Jump:', 2)
# ('Idx:', 86, 'v_CricketShot_g11_c04', 'Length:', 103, 'Jump:', 2)
# ('Idx:', 87, 'v_PushUps_g05_c04', 'Length:', 147, 'Jump:', 2)
# ('Idx:', 88, 'v_MilitaryParade_g04_c03', 'Length:', 148, 'Jump:', 2)
# ('Idx:', 89, 'v_HighJump_g02_c02', 'Length:', 134, 'Jump:', 2)
# ('Idx:', 90, 'v_Kayaking_g03_c03', 'Length:', 159, 'Jump:', 2)
# ('Idx:', 91, 'v_PlayingGuitar_g06_c01', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 92, 'v_PlayingGuitar_g15_c02', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 93, 'v_PlayingPiano_g15_c02', 'Length:', 202, 'Jump:', 2)
# ('Idx:', 94, 'v_Surfing_g10_c01', 'Length:', 241, 'Jump:', 2)
# ('Idx:', 95, 'v_WallPushups_g24_c02', 'Length:', 103, 'Jump:', 2)
# ('Idx:', 96, 'v_PlayingGuitar_g12_c05', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 97, 'v_CricketShot_g06_c05', 'Length:', 119, 'Jump:', 2)
# ('Idx:', 98, 'v_PlayingGuitar_g25_c05', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 99, 'v_Surfing_g07_c03', 'Length:', 193, 'Jump:', 2)
# ('Idx:', 100, 'v_BlowDryHair_g15_c02', 'Length:', 109, 'Jump:', 2)
# ('Idx:', 101, 'v_PlayingDhol_g22_c06', 'Length:', 252, 'Jump:', 2)
# ('Idx:', 102, 'v_PlayingDhol_g01_c06', 'Length:', 192, 'Jump:', 2)
# ('Idx:', 103, 'v_BlowDryHair_g05_c02', 'Length:', 148, 'Jump:', 2)
# ('Idx:', 104, 'v_BlowDryHair_g19_c01', 'Length:', 203, 'Jump:', 2)
# ('Idx:', 105, 'v_BabyCrawling_g17_c04', 'Length:', 172, 'Jump:', 2)
# ('Idx:', 106, 'v_BrushingTeeth_g25_c05', 'Length:', 222, 'Jump:', 2)
# ('Idx:', 107, 'v_MilitaryParade_g22_c03', 'Length:', 139, 'Jump:', 2)
# ('Idx:', 108, 'v_PlayingGuitar_g07_c01', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 109, 'v_CricketShot_g21_c04', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 110, 'v_BabyCrawling_g02_c03', 'Length:', 115, 'Jump:', 2)
# ('Idx:', 111, 'v_PlayingPiano_g23_c01', 'Length:', 217, 'Jump:', 2)
# ('Idx:', 112, 'v_IceDancing_g04_c07', 'Length:', 252, 'Jump:', 2)
# ('Idx:', 113, 'v_CricketShot_g05_c02', 'Length:', 61, 'Jump:', 2)
# ('Idx:', 114, 'v_Surfing_g23_c01', 'Length:', 126, 'Jump:', 2)
# ('Idx:', 115, 'v_IceDancing_g06_c04', 'Length:', 245, 'Jump:', 2)
# ('Idx:', 116, 'v_ApplyEyeMakeup_g10_c02', 'Length:', 96, 'Jump:', 2)
# ('Idx:', 117, 'v_IceDancing_g11_c03', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 118, 'v_CleanAndJerk_g17_c03', 'Length:', 135, 'Jump:', 2)
# ('Idx:', 119, 'v_PlayingGuitar_g03_c04', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 120, 'v_PlayingPiano_g06_c02', 'Length:', 219, 'Jump:', 2)
# ('Idx:', 121, 'v_PlayingPiano_g10_c04', 'Length:', 221, 'Jump:', 2)
# ('Idx:', 122, 'v_BabyCrawling_g02_c06', 'Length:', 188, 'Jump:', 2)
# ('Idx:', 123, 'v_WallPushups_g19_c05', 'Length:', 70, 'Jump:', 2)
# ('Idx:', 124, 'v_WallPushups_g03_c04', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 125, 'v_Surfing_g25_c01', 'Length:', 108, 'Jump:', 2)
# ('Idx:', 126, 'v_Kayaking_g04_c01', 'Length:', 206, 'Jump:', 2)
# ('Idx:', 127, 'v_PlayingGuitar_g13_c06', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 128, 'v_StillRings_g20_c04', 'Length:', 166, 'Jump:', 2)
# ('Idx:', 129, 'v_BabyCrawling_g21_c03', 'Length:', 143, 'Jump:', 2)
# ('Idx:', 130, 'v_Kayaking_g18_c03', 'Length:', 164, 'Jump:', 2)
# ('Idx:', 131, 'v_ApplyEyeMakeup_g17_c03', 'Length:', 92, 'Jump:', 2)
# ('Idx:', 132, 'v_CricketShot_g23_c02', 'Length:', 102, 'Jump:', 2)
# ('Idx:', 133, 'v_MilitaryParade_g10_c02', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 134, 'v_WallPushups_g14_c02', 'Length:', 134, 'Jump:', 2)
# ('Idx:', 135, 'v_Hammering_g05_c04', 'Length:', 71, 'Jump:', 2)
# ('Idx:', 136, 'v_BlowDryHair_g24_c02', 'Length:', 81, 'Jump:', 2)
# ('Idx:', 137, 'v_IceDancing_g07_c06', 'Length:', 253, 'Jump:', 2)
# ('Idx:', 138, 'v_BabyCrawling_g20_c02', 'Length:', 239, 'Jump:', 2)
# ('Idx:', 139, 'v_Kayaking_g08_c04', 'Length:', 167, 'Jump:', 2)
# ('Idx:', 140, 'v_ApplyEyeMakeup_g21_c01', 'Length:', 179, 'Jump:', 2)
# ('Idx:', 141, 'v_Kayaking_g10_c05', 'Length:', 172, 'Jump:', 2)
# ('Idx:', 142, 'v_PlayingPiano_g11_c02', 'Length:', 221, 'Jump:', 2)
# ('Idx:', 143, 'v_BlowDryHair_g22_c01', 'Length:', 232, 'Jump:', 2)
# ('Idx:', 144, 'v_Surfing_g09_c02', 'Length:', 253, 'Jump:', 2)
# ('Idx:', 145, 'v_MilitaryParade_g09_c04', 'Length:', 102, 'Jump:', 2)
# ('Idx:', 146, 'v_Surfing_g11_c04', 'Length:', 175, 'Jump:', 2)
# ('Idx:', 147, 'v_PlayingDhol_g09_c01', 'Length:', 269, 'Jump:', 2)
# ('Idx:', 148, 'v_Kayaking_g06_c04', 'Length:', 152, 'Jump:', 2)
# ('Idx:', 149, 'v_BabyCrawling_g16_c04', 'Length:', 205, 'Jump:', 2)
# ('Idx:', 150, 'v_PlayingDaf_g17_c04', 'Length:', 168, 'Jump:', 2)
# ('Idx:', 151, 'v_ApplyEyeMakeup_g06_c05', 'Length:', 279, 'Jump:', 2)
# ('Idx:', 152, 'v_WallPushups_g11_c05', 'Length:', 117, 'Jump:', 2)
# ('Idx:', 153, 'v_IceDancing_g22_c01', 'Length:', 255, 'Jump:', 2)
# ('Idx:', 154, 'v_BrushingTeeth_g22_c06', 'Length:', 181, 'Jump:', 2)
# ('Idx:', 155, 'v_CricketShot_g24_c01', 'Length:', 68, 'Jump:', 2)
# ('Idx:', 156, 'v_HighJump_g16_c01', 'Length:', 88, 'Jump:', 2)
# ('Idx:', 157, 'v_BabyCrawling_g25_c02', 'Length:', 150, 'Jump:', 2)
# ('Idx:', 158, 'v_Kayaking_g15_c01', 'Length:', 162, 'Jump:', 2)
# ('Idx:', 159, 'v_ApplyEyeMakeup_g23_c04', 'Length:', 198, 'Jump:', 2)
# ('Idx:', 160, 'v_ApplyEyeMakeup_g07_c03', 'Length:', 131, 'Jump:', 2)
# ('Idx:', 161, 'v_Shotput_g21_c04', 'Length:', 73, 'Jump:', 2)
# ('Idx:', 162, 'v_Hammering_g15_c07', 'Length:', 119, 'Jump:', 2)
# ('Idx:', 163, 'v_ApplyEyeMakeup_g07_c02', 'Length:', 166, 'Jump:', 2)
# ('Idx:', 164, 'v_Hammering_g25_c04', 'Length:', 73, 'Jump:', 2)
# ('Idx:', 165, 'v_StillRings_g12_c02', 'Length:', 255, 'Jump:', 2)
# ('Idx:', 166, 'v_CleanAndJerk_g06_c02', 'Length:', 191, 'Jump:', 2)
# ('Idx:', 167, 'v_MilitaryParade_g04_c01', 'Length:', 134, 'Jump:', 2)
# ('Idx:', 168, 'v_ApplyEyeMakeup_g16_c04', 'Length:', 96, 'Jump:', 2)
# ('Idx:', 169, 'v_PushUps_g16_c03', 'Length:', 30, 'Jump:', 2)
# ('Idx:', 170, 'v_BabyCrawling_g23_c04', 'Length:', 177, 'Jump:', 2)
# ('Idx:', 171, 'v_PlayingDhol_g23_c04', 'Length:', 288, 'Jump:', 2)
# ('Idx:', 172, 'v_Shotput_g24_c01', 'Length:', 108, 'Jump:', 2)
# ('Idx:', 173, 'v_PlayingDaf_g14_c03', 'Length:', 253, 'Jump:', 2)
# ('Idx:', 174, 'v_MilitaryParade_g25_c07', 'Length:', 125, 'Jump:', 2)
# ('Idx:', 175, 'v_Shotput_g09_c02', 'Length:', 69, 'Jump:', 2)
# ('Idx:', 176, 'v_WallPushups_g05_c05', 'Length:', 75, 'Jump:', 2)
# ('Idx:', 177, 'v_PlayingDhol_g23_c05', 'Length:', 263, 'Jump:', 2)
# ('Idx:', 178, 'v_CleanAndJerk_g05_c04', 'Length:', 203, 'Jump:', 2)
# ('Idx:', 179, 'v_BlowDryHair_g22_c02', 'Length:', 121, 'Jump:', 2)
# ('Idx:', 180, 'v_MilitaryParade_g03_c04', 'Length:', 109, 'Jump:', 2)
# ('Idx:', 181, 'v_ApplyEyeMakeup_g10_c05', 'Length:', 118, 'Jump:', 2)
# ('Idx:', 182, 'v_ApplyEyeMakeup_g03_c06', 'Length:', 150, 'Jump:', 2)
# ('Idx:', 183, 'v_Surfing_g18_c01', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 184, 'v_IceDancing_g14_c03', 'Length:', 252, 'Jump:', 2)
# ('Idx:', 185, 'v_BlowDryHair_g10_c04', 'Length:', 291, 'Jump:', 2)
# ('Idx:', 186, 'v_WallPushups_g21_c03', 'Length:', 147, 'Jump:', 2)
# ('Idx:', 187, 'v_PlayingGuitar_g05_c05', 'Length:', 231, 'Jump:', 2)
# ('Idx:', 188, 'v_Kayaking_g09_c04', 'Length:', 197, 'Jump:', 2)
# ('Idx:', 189, 'v_WallPushups_g02_c01', 'Length:', 80, 'Jump:', 2)
# ('Idx:', 190, 'v_BlowDryHair_g04_c02', 'Length:', 203, 'Jump:', 2)
# ('Idx:', 191, 'v_BlowDryHair_g10_c05', 'Length:', 184, 'Jump:', 2)
# ('Idx:', 192, 'v_BrushingTeeth_g17_c03', 'Length:', 155, 'Jump:', 2)
# ('Idx:', 193, 'v_CricketShot_g10_c02', 'Length:', 81, 'Jump:', 2)
# ('Idx:', 194, 'v_PlayingGuitar_g21_c05', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 195, 'v_WallPushups_g18_c03', 'Length:', 102, 'Jump:', 2)
# ('Idx:', 196, 'v_IceDancing_g23_c01', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 197, 'v_ApplyEyeMakeup_g15_c04', 'Length:', 185, 'Jump:', 2)
# ('Idx:', 198, 'v_BabyCrawling_g16_c06', 'Length:', 189, 'Jump:', 2)
# ('Idx:', 199, 'v_Surfing_g07_c02', 'Length:', 238, 'Jump:', 2)
# ('Idx:', 200, 'v_Kayaking_g20_c04', 'Length:', 151, 'Jump:', 2)
# ('Idx:', 201, 'v_PlayingGuitar_g25_c06', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 202, 'v_BlowDryHair_g17_c02', 'Length:', 250, 'Jump:', 2)
# ('Idx:', 203, 'v_WallPushups_g08_c04', 'Length:', 119, 'Jump:', 2)
# ('Idx:', 204, 'v_IceDancing_g05_c06', 'Length:', 240, 'Jump:', 2)
# ('Idx:', 205, 'v_Shotput_g15_c06', 'Length:', 63, 'Jump:', 2)
# ('Idx:', 206, 'v_StillRings_g06_c03', 'Length:', 125, 'Jump:', 2)
# ('Idx:', 207, 'v_Kayaking_g06_c06', 'Length:', 158, 'Jump:', 2)
# ('Idx:', 208, 'v_Surfing_g15_c03', 'Length:', 106, 'Jump:', 2)
# ('Idx:', 209, 'v_IceDancing_g12_c07', 'Length:', 252, 'Jump:', 2)
# ('Idx:', 210, 'v_Hammering_g22_c07', 'Length:', 175, 'Jump:', 2)
# ('Idx:', 211, 'v_PlayingGuitar_g10_c07', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 212, 'v_HighJump_g22_c01', 'Length:', 105, 'Jump:', 2)
# ('Idx:', 213, 'v_PlayingDhol_g07_c04', 'Length:', 251, 'Jump:', 2)
# ('Idx:', 214, 'v_MilitaryParade_g25_c02', 'Length:', 90, 'Jump:', 2)
# ('Idx:', 215, 'v_Surfing_g06_c01', 'Length:', 262, 'Jump:', 2)
# ('Idx:', 216, 'v_PlayingDaf_g06_c07', 'Length:', 217, 'Jump:', 2)
# ('Idx:', 217, 'v_BrushingTeeth_g03_c01', 'Length:', 238, 'Jump:', 2)
# ('Idx:', 218, 'v_Surfing_g05_c01', 'Length:', 234, 'Jump:', 2)
# ('Idx:', 219, 'v_WallPushups_g25_c03', 'Length:', 147, 'Jump:', 2)
# ('Idx:', 220, 'v_BabyCrawling_g25_c06', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 221, 'v_Surfing_g23_c02', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 222, 'v_PlayingDhol_g11_c01', 'Length:', 255, 'Jump:', 2)
# ('Idx:', 223, 'v_IceDancing_g20_c04', 'Length:', 248, 'Jump:', 2)
# ('Idx:', 224, 'v_PlayingDaf_g18_c07', 'Length:', 243, 'Jump:', 2)
# ('Idx:', 225, 'v_Shotput_g16_c04', 'Length:', 93, 'Jump:', 2)
# ('Idx:', 226, 'v_StillRings_g05_c03', 'Length:', 119, 'Jump:', 2)
# ('Idx:', 227, 'v_CricketShot_g10_c07', 'Length:', 105, 'Jump:', 2)
# ('Idx:', 228, 'v_Surfing_g05_c02', 'Length:', 294, 'Jump:', 2)
# ('Idx:', 229, 'v_StillRings_g02_c04', 'Length:', 153, 'Jump:', 2)
# ('Idx:', 230, 'v_Shotput_g01_c05', 'Length:', 95, 'Jump:', 2)
# ('Idx:', 231, 'v_IceDancing_g05_c03', 'Length:', 239, 'Jump:', 2)
# ('Idx:', 232, 'v_StillRings_g24_c03', 'Length:', 79, 'Jump:', 2)
# ('Idx:', 233, 'v_CleanAndJerk_g07_c04', 'Length:', 282, 'Jump:', 2)
# ('Idx:', 234, 'v_PlayingGuitar_g18_c01', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 235, 'v_Hammering_g03_c02', 'Length:', 97, 'Jump:', 2)
# ('Idx:', 236, 'v_PlayingGuitar_g23_c02', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 237, 'v_StillRings_g05_c01', 'Length:', 83, 'Jump:', 2)
# ('Idx:', 238, 'v_BrushingTeeth_g10_c01', 'Length:', 209, 'Jump:', 2)
# ('Idx:', 239, 'v_PlayingGuitar_g20_c07', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 240, 'v_PlayingDaf_g18_c06', 'Length:', 240, 'Jump:', 2)
# ('Idx:', 241, 'v_CleanAndJerk_g15_c03', 'Length:', 162, 'Jump:', 2)
# ('Idx:', 242, 'v_BabyCrawling_g14_c02', 'Length:', 106, 'Jump:', 2)
# ('Idx:', 243, 'v_Hammering_g12_c02', 'Length:', 85, 'Jump:', 2)
# ('Idx:', 244, 'v_CleanAndJerk_g12_c02', 'Length:', 97, 'Jump:', 2)
# ('Idx:', 245, 'v_HighJump_g17_c01', 'Length:', 131, 'Jump:', 2)
# ('Idx:', 246, 'v_PlayingPiano_g13_c02', 'Length:', 212, 'Jump:', 2)
# ('Idx:', 247, 'v_Hammering_g09_c01', 'Length:', 148, 'Jump:', 2)
# ('Idx:', 248, 'v_BabyCrawling_g21_c04', 'Length:', 187, 'Jump:', 2)
# ('Idx:', 249, 'v_IceDancing_g17_c05', 'Length:', 244, 'Jump:', 2)
# ('Idx:', 250, 'v_PlayingDaf_g11_c03', 'Length:', 268, 'Jump:', 2)
# ('Idx:', 251, 'v_PushUps_g01_c04', 'Length:', 101, 'Jump:', 2)
# ('Idx:', 252, 'v_WallPushups_g17_c05', 'Length:', 113, 'Jump:', 2)
# ('Idx:', 253, 'v_BlowDryHair_g04_c05', 'Length:', 115, 'Jump:', 2)
# ('Idx:', 254, 'v_HighJump_g21_c01', 'Length:', 132, 'Jump:', 2)
# ('Idx:', 255, 'v_PlayingPiano_g07_c04', 'Length:', 202, 'Jump:', 2)
# ('Idx:', 256, 'v_PlayingDaf_g23_c01', 'Length:', 232, 'Jump:', 2)
# ('Idx:', 257, 'v_PlayingDaf_g03_c01', 'Length:', 184, 'Jump:', 2)
# ('Idx:', 258, 'v_PlayingPiano_g05_c02', 'Length:', 222, 'Jump:', 2)
# ('Idx:', 259, 'v_PushUps_g18_c02', 'Length:', 68, 'Jump:', 2)
# ('Idx:', 260, 'v_BrushingTeeth_g14_c04', 'Length:', 227, 'Jump:', 2)
# ('Idx:', 261, 'v_IceDancing_g11_c01', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 262, 'v_HighJump_g23_c04', 'Length:', 82, 'Jump:', 2)
# ('Idx:', 263, 'v_CricketShot_g11_c06', 'Length:', 138, 'Jump:', 2)
# ('Idx:', 264, 'v_CricketShot_g19_c03', 'Length:', 78, 'Jump:', 2)
# ('Idx:', 265, 'v_IceDancing_g12_c02', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 266, 'v_Shotput_g08_c04', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 267, 'v_Surfing_g02_c03', 'Length:', 276, 'Jump:', 2)
# ('Idx:', 268, 'v_BlowDryHair_g14_c03', 'Length:', 196, 'Jump:', 2)
# ('Idx:', 269, 'v_Kayaking_g02_c01', 'Length:', 195, 'Jump:', 2)
# ('Idx:', 270, 'v_PlayingPiano_g12_c01', 'Length:', 212, 'Jump:', 2)
# ('Idx:', 271, 'v_Surfing_g14_c02', 'Length:', 202, 'Jump:', 2)
# ('Idx:', 272, 'v_IceDancing_g10_c02', 'Length:', 257, 'Jump:', 2)
# ('Idx:', 273, 'v_Surfing_g18_c04', 'Length:', 117, 'Jump:', 2)
# ('Idx:', 274, 'v_CricketShot_g12_c01', 'Length:', 111, 'Jump:', 2)
# ('Idx:', 275, 'v_WallPushups_g13_c02', 'Length:', 122, 'Jump:', 2)
# ('Idx:', 276, 'v_IceDancing_g05_c01', 'Length:', 245, 'Jump:', 2)
# ('Idx:', 277, 'v_Shotput_g06_c07', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 278, 'v_BabyCrawling_g19_c03', 'Length:', 158, 'Jump:', 2)
# ('Idx:', 279, 'v_CleanAndJerk_g19_c03', 'Length:', 237, 'Jump:', 2)
# ('Idx:', 280, 'v_ApplyEyeMakeup_g19_c03', 'Length:', 124, 'Jump:', 2)
# ('Idx:', 281, 'v_HighJump_g22_c03', 'Length:', 118, 'Jump:', 2)
# ('Idx:', 282, 'v_WallPushups_g15_c02', 'Length:', 59, 'Jump:', 2)
# ('Idx:', 283, 'v_IceDancing_g19_c06', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 284, 'v_WallPushups_g25_c04', 'Length:', 147, 'Jump:', 2)
# ('Idx:', 285, 'v_IceDancing_g21_c06', 'Length:', 248, 'Jump:', 2)
# ('Idx:', 286, 'v_PlayingDaf_g16_c01', 'Length:', 262, 'Jump:', 2)
# ('Idx:', 287, 'v_ApplyEyeMakeup_g17_c04', 'Length:', 103, 'Jump:', 2)
# ('Idx:', 288, 'v_BrushingTeeth_g07_c05', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 289, 'v_BrushingTeeth_g08_c01', 'Length:', 175, 'Jump:', 2)
# ('Idx:', 290, 'v_CricketShot_g22_c03', 'Length:', 155, 'Jump:', 2)
# ('Idx:', 291, 'v_MilitaryParade_g11_c04', 'Length:', 119, 'Jump:', 2)
# ('Idx:', 292, 'v_CleanAndJerk_g07_c03', 'Length:', 225, 'Jump:', 2)
# ('Idx:', 293, 'v_IceDancing_g08_c01', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 294, 'v_Kayaking_g21_c03', 'Length:', 149, 'Jump:', 2)
# ('Idx:', 295, 'v_Hammering_g22_c05', 'Length:', 159, 'Jump:', 2)
# ('Idx:', 296, 'v_Shotput_g04_c03', 'Length:', 83, 'Jump:', 2)
# ('Idx:', 297, 'v_BrushingTeeth_g22_c04', 'Length:', 183, 'Jump:', 2)
# ('Idx:', 298, 'v_PlayingDhol_g22_c03', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 299, 'v_Hammering_g12_c04', 'Length:', 103, 'Jump:', 2)
# ('Idx:', 300, 'v_IceDancing_g01_c04', 'Length:', 255, 'Jump:', 2)
# ('Idx:', 301, 'v_IceDancing_g25_c05', 'Length:', 243, 'Jump:', 2)
# ('Idx:', 302, 'v_BrushingTeeth_g13_c03', 'Length:', 158, 'Jump:', 2)
# ('Idx:', 303, 'v_IceDancing_g02_c01', 'Length:', 253, 'Jump:', 2)
# ('Idx:', 304, 'v_Hammering_g16_c02', 'Length:', 63, 'Jump:', 2)
# ('Idx:', 305, 'v_BlowDryHair_g25_c04', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 306, 'v_Shotput_g06_c02', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 307, 'v_Surfing_g02_c06', 'Length:', 275, 'Jump:', 2)
# ('Idx:', 308, 'v_StillRings_g15_c01', 'Length:', 163, 'Jump:', 2)
# ('Idx:', 309, 'v_MilitaryParade_g02_c01', 'Length:', 90, 'Jump:', 2)
# ('Idx:', 310, 'v_StillRings_g01_c02', 'Length:', 204, 'Jump:', 2)
# ('Idx:', 311, 'v_PushUps_g10_c01', 'Length:', 66, 'Jump:', 2)
# ('Idx:', 312, 'v_WallPushups_g03_c02', 'Length:', 115, 'Jump:', 2)
# ('Idx:', 313, 'v_BrushingTeeth_g10_c03', 'Length:', 207, 'Jump:', 2)
# ('Idx:', 314, 'v_MilitaryParade_g24_c04', 'Length:', 103, 'Jump:', 2)
# ('Idx:', 315, 'v_PushUps_g01_c02', 'Length:', 50, 'Jump:', 2)
# ('Idx:', 316, 'v_IceDancing_g17_c01', 'Length:', 256, 'Jump:', 2)
# ('Idx:', 317, 'v_BlowDryHair_g16_c01', 'Length:', 116, 'Jump:', 2)
# ('Idx:', 318, 'v_ApplyEyeMakeup_g20_c02', 'Length:', 156, 'Jump:', 2)
# ('Idx:', 319, 'v_PlayingPiano_g04_c03', 'Length:', 202, 'Jump:', 2)
# ('Idx:', 320, 'v_Surfing_g05_c04', 'Length:', 238, 'Jump:', 2)
# ('Idx:', 321, 'v_Shotput_g07_c06', 'Length:', 57, 'Jump:', 2)
# ('Idx:', 322, 'v_BabyCrawling_g14_c04', 'Length:', 220, 'Jump:', 2)
# ('Idx:', 323, 'v_Kayaking_g02_c03', 'Length:', 178, 'Jump:', 2)
# ('Idx:', 324, 'v_CleanAndJerk_g09_c01', 'Length:', 250, 'Jump:', 2)
# ('Idx:', 325, 'v_ApplyEyeMakeup_g11_c01', 'Length:', 138, 'Jump:', 2)
# ('Idx:', 326, 'v_BlowDryHair_g10_c07', 'Length:', 174, 'Jump:', 2)
# ('Idx:', 327, 'v_Kayaking_g09_c06', 'Length:', 202, 'Jump:', 2)
# ('Idx:', 328, 'v_ApplyEyeMakeup_g22_c01', 'Length:', 168, 'Jump:', 2)
# ('Idx:', 329, 'v_Hammering_g18_c01', 'Length:', 86, 'Jump:', 2)
# ('Idx:', 330, 'v_ApplyEyeMakeup_g25_c04', 'Length:', 175, 'Jump:', 2)
# ('Idx:', 331, 'v_CricketShot_g03_c05', 'Length:', 102, 'Jump:', 2)
# ('Idx:', 332, 'v_MilitaryParade_g12_c03', 'Length:', 127, 'Jump:', 2)
# ('Idx:', 333, 'v_CricketShot_g10_c01', 'Length:', 110, 'Jump:', 2)
# ('Idx:', 334, 'v_PlayingPiano_g02_c04', 'Length:', 207, 'Jump:', 2)
# ('Idx:', 335, 'v_ApplyEyeMakeup_g05_c02', 'Length:', 262, 'Jump:', 2)
# ('Idx:', 336, 'v_CricketShot_g16_c07', 'Length:', 47, 'Jump:', 2)
# ('Idx:', 337, 'v_Hammering_g14_c04', 'Length:', 273, 'Jump:', 2)
# ('Idx:', 338, 'v_Surfing_g13_c03', 'Length:', 172, 'Jump:', 2)
# ('Idx:', 339, 'v_CricketShot_g04_c02', 'Length:', 113, 'Jump:', 2)
# ('Idx:', 340, 'v_HighJump_g03_c02', 'Length:', 135, 'Jump:', 2)
# ('Idx:', 341, 'v_Hammering_g18_c04', 'Length:', 112, 'Jump:', 2)
# ('Idx:', 342, 'v_PlayingGuitar_g06_c06', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 343, 'v_PushUps_g03_c02', 'Length:', 60, 'Jump:', 2)
# ('Idx:', 344, 'v_Kayaking_g01_c05', 'Length:', 198, 'Jump:', 2)
# ('Idx:', 345, 'v_ApplyEyeMakeup_g06_c01', 'Length:', 137, 'Jump:', 2)
# ('Idx:', 346, 'v_Kayaking_g06_c01', 'Length:', 148, 'Jump:', 2)
# ('Idx:', 347, 'v_BabyCrawling_g15_c04', 'Length:', 177, 'Jump:', 2)
# ('Idx:', 348, 'v_PlayingDhol_g05_c06', 'Length:', 292, 'Jump:', 2)
# ('Idx:', 349, 'v_MilitaryParade_g09_c06', 'Length:', 132, 'Jump:', 2)
# ('Idx:', 350, 'v_MilitaryParade_g17_c03', 'Length:', 135, 'Jump:', 2)
# ('Idx:', 351, 'v_HighJump_g12_c03', 'Length:', 89, 'Jump:', 2)
# ('Idx:', 352, 'v_StillRings_g22_c02', 'Length:', 269, 'Jump:', 2)
# ('Idx:', 353, 'v_MilitaryParade_g10_c04', 'Length:', 86, 'Jump:', 2)
# ('Idx:', 354, 'v_CleanAndJerk_g11_c04', 'Length:', 204, 'Jump:', 2)
# ('Idx:', 355, 'v_HighJump_g22_c05', 'Length:', 92, 'Jump:', 2)
# ('Idx:', 356, 'v_ApplyEyeMakeup_g24_c04', 'Length:', 206, 'Jump:', 2)
# ('Idx:', 357, 'v_Hammering_g10_c01', 'Length:', 128, 'Jump:', 2)
# ('Idx:', 358, 'v_IceDancing_g10_c06', 'Length:', 251, 'Jump:', 2)
# ('Idx:', 359, 'v_BabyCrawling_g11_c03', 'Length:', 97, 'Jump:', 2)
# ('Idx:', 360, 'v_IceDancing_g20_c06', 'Length:', 257, 'Jump:', 2)
# ('Idx:', 361, 'v_HighJump_g15_c03', 'Length:', 120, 'Jump:', 2)
# ('Idx:', 362, 'v_Kayaking_g23_c01', 'Length:', 173, 'Jump:', 2)
# ('Idx:', 363, 'v_BlowDryHair_g03_c02', 'Length:', 239, 'Jump:', 2)
# ('Idx:', 364, 'v_PlayingPiano_g10_c03', 'Length:', 214, 'Jump:', 2)
# ('Idx:', 365, 'v_WallPushups_g15_c01', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 366, 'v_MilitaryParade_g19_c03', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 367, 'v_ApplyEyeMakeup_g05_c05', 'Length:', 225, 'Jump:', 2)
# ('Idx:', 368, 'v_CricketShot_g16_c05', 'Length:', 44, 'Jump:', 2)
# ('Idx:', 369, 'v_CleanAndJerk_g02_c04', 'Length:', 290, 'Jump:', 2)
# ('Idx:', 370, 'v_BlowDryHair_g06_c07', 'Length:', 163, 'Jump:', 2)
# ('Idx:', 371, 'v_WallPushups_g20_c04', 'Length:', 98, 'Jump:', 2)
# ('Idx:', 372, 'v_BrushingTeeth_g21_c03', 'Length:', 282, 'Jump:', 2)
# ('Idx:', 373, 'v_Surfing_g09_c05', 'Length:', 252, 'Jump:', 2)
# ('Idx:', 374, 'v_PlayingDhol_g21_c04', 'Length:', 261, 'Jump:', 2)
# ('Idx:', 375, 'v_PlayingDhol_g11_c03', 'Length:', 253, 'Jump:', 2)
# ('Idx:', 376, 'v_HighJump_g02_c07', 'Length:', 125, 'Jump:', 2)
# ('Idx:', 377, 'v_IceDancing_g25_c04', 'Length:', 263, 'Jump:', 2)
# ('Idx:', 378, 'v_IceDancing_g02_c02', 'Length:', 249, 'Jump:', 2)
# ('Idx:', 379, 'v_Kayaking_g17_c01', 'Length:', 165, 'Jump:', 2)
# ('Idx:', 380, 'v_PlayingDhol_g08_c02', 'Length:', 280, 'Jump:', 2)
# ('Idx:', 381, 'v_Shotput_g20_c01', 'Length:', 112, 'Jump:', 2)
# ('Idx:', 382, 'v_Shotput_g25_c05', 'Length:', 81, 'Jump:', 2)
# ('Idx:', 383, 'v_Shotput_g01_c07', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 384, 'v_PlayingGuitar_g11_c04', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 385, 'v_HighJump_g10_c02', 'Length:', 114, 'Jump:', 2)
# ('Idx:', 386, 'v_ApplyEyeMakeup_g22_c04', 'Length:', 206, 'Jump:', 2)
# ('Idx:', 387, 'v_PlayingGuitar_g11_c06', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 388, 'v_Shotput_g15_c01', 'Length:', 63, 'Jump:', 2)
# ('Idx:', 389, 'v_PushUps_g12_c04', 'Length:', 69, 'Jump:', 2)
# ('Idx:', 390, 'v_Kayaking_g20_c02', 'Length:', 159, 'Jump:', 2)
# ('Idx:', 391, 'v_StillRings_g07_c02', 'Length:', 268, 'Jump:', 2)
# ('Idx:', 392, 'v_ApplyEyeMakeup_g18_c01', 'Length:', 157, 'Jump:', 2)
# ('Idx:', 393, 'v_Shotput_g01_c04', 'Length:', 89, 'Jump:', 2)
# ('Idx:', 394, 'v_BabyCrawling_g03_c02', 'Length:', 178, 'Jump:', 2)
# ('Idx:', 395, 'v_Hammering_g06_c01', 'Length:', 89, 'Jump:', 2)
# ('Idx:', 396, 'v_ApplyEyeMakeup_g21_c04', 'Length:', 225, 'Jump:', 2)
# ('Idx:', 397, 'v_BabyCrawling_g12_c06', 'Length:', 122, 'Jump:', 2)
# ('Idx:', 398, 'v_WallPushups_g11_c03', 'Length:', 137, 'Jump:', 2)
# ('Idx:', 399, 'v_Hammering_g02_c01', 'Length:', 71, 'Jump:', 2)
# ('Idx:', 400, 'v_CleanAndJerk_g13_c04', 'Length:', 284, 'Jump:', 2)
# ('Idx:', 401, 'v_Hammering_g09_c03', 'Length:', 115, 'Jump:', 2)
# ('Idx:', 402, 'v_Kayaking_g19_c01', 'Length:', 202, 'Jump:', 2)
# ('Idx:', 403, 'v_Kayaking_g03_c04', 'Length:', 184, 'Jump:', 2)
# ('Idx:', 404, 'v_ApplyEyeMakeup_g08_c05', 'Length:', 274, 'Jump:', 2)
# ('Idx:', 405, 'v_WallPushups_g22_c04', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 406, 'v_WallPushups_g11_c02', 'Length:', 159, 'Jump:', 2)
# ('Idx:', 407, 'v_CricketShot_g19_c04', 'Length:', 81, 'Jump:', 2)
# ('Idx:', 408, 'v_Surfing_g06_c04', 'Length:', 137, 'Jump:', 2)
# ('Idx:', 409, 'v_BrushingTeeth_g11_c03', 'Length:', 237, 'Jump:', 2)
# ('Idx:', 410, 'v_Shotput_g05_c06', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 411, 'v_ApplyEyeMakeup_g09_c05', 'Length:', 192, 'Jump:', 2)
# ('Idx:', 412, 'v_BlowDryHair_g20_c01', 'Length:', 155, 'Jump:', 2)
# ('Idx:', 413, 'v_ApplyEyeMakeup_g15_c03', 'Length:', 230, 'Jump:', 2)
# ('Idx:', 414, 'v_PushUps_g24_c04', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 415, 'v_PlayingDhol_g18_c04', 'Length:', 180, 'Jump:', 2)
# ('Idx:', 416, 'v_HighJump_g06_c02', 'Length:', 129, 'Jump:', 2)
# ('Idx:', 417, 'v_ApplyEyeMakeup_g16_c05', 'Length:', 199, 'Jump:', 2)
# ('Idx:', 418, 'v_BrushingTeeth_g23_c03', 'Length:', 252, 'Jump:', 2)
# ('Idx:', 419, 'v_Surfing_g12_c07', 'Length:', 264, 'Jump:', 2)
# ('Idx:', 420, 'v_BlowDryHair_g02_c02', 'Length:', 135, 'Jump:', 2)
# ('Idx:', 421, 'v_MilitaryParade_g09_c02', 'Length:', 120, 'Jump:', 2)
# ('Idx:', 422, 'v_BabyCrawling_g14_c03', 'Length:', 174, 'Jump:', 2)
# ('Idx:', 423, 'v_MilitaryParade_g05_c02', 'Length:', 107, 'Jump:', 2)
# ('Idx:', 424, 'v_Hammering_g17_c06', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 425, 'v_BrushingTeeth_g17_c05', 'Length:', 121, 'Jump:', 2)
# ('Idx:', 426, 'v_Hammering_g23_c06', 'Length:', 154, 'Jump:', 2)
# ('Idx:', 427, 'v_BlowDryHair_g23_c03', 'Length:', 153, 'Jump:', 2)
# ('Idx:', 428, 'v_PlayingDaf_g07_c01', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 429, 'v_MilitaryParade_g15_c07', 'Length:', 155, 'Jump:', 2)
# ('Idx:', 430, 'v_PlayingGuitar_g11_c03', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 431, 'v_PlayingGuitar_g24_c02', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 432, 'v_Shotput_g04_c02', 'Length:', 74, 'Jump:', 2)
# ('Idx:', 433, 'v_PlayingGuitar_g04_c04', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 434, 'v_CricketShot_g13_c01', 'Length:', 47, 'Jump:', 2)
# ('Idx:', 435, 'v_CricketShot_g22_c05', 'Length:', 180, 'Jump:', 2)
# ('Idx:', 436, 'v_ApplyEyeMakeup_g25_c03', 'Length:', 123, 'Jump:', 2)
# ('Idx:', 437, 'v_Kayaking_g07_c03', 'Length:', 156, 'Jump:', 2)
# ('Idx:', 438, 'v_HighJump_g02_c03', 'Length:', 118, 'Jump:', 2)
# ('Idx:', 439, 'v_BabyCrawling_g07_c03', 'Length:', 169, 'Jump:', 2)
# ('Idx:', 440, 'v_ApplyEyeMakeup_g19_c02', 'Length:', 241, 'Jump:', 2)
# ('Idx:', 441, 'v_IceDancing_g24_c06', 'Length:', 243, 'Jump:', 2)
# ('Idx:', 442, 'v_MilitaryParade_g24_c01', 'Length:', 100, 'Jump:', 2)
# ('Idx:', 443, 'v_ApplyEyeMakeup_g24_c01', 'Length:', 256, 'Jump:', 2)
# ('Idx:', 444, 'v_Surfing_g08_c04', 'Length:', 234, 'Jump:', 2)
# ('Idx:', 445, 'v_Shotput_g07_c01', 'Length:', 76, 'Jump:', 2)
# ('Idx:', 446, 'v_HighJump_g07_c03', 'Length:', 120, 'Jump:', 2)
# ('Idx:', 447, 'v_CleanAndJerk_g04_c03', 'Length:', 143, 'Jump:', 2)
# ('Idx:', 448, 'v_MilitaryParade_g18_c02', 'Length:', 143, 'Jump:', 2)
# ('Idx:', 449, 'v_CleanAndJerk_g15_c02', 'Length:', 80, 'Jump:', 2)
# ('Idx:', 450, 'v_Surfing_g16_c07', 'Length:', 233, 'Jump:', 2)
# ('Idx:', 451, 'v_PushUps_g11_c01', 'Length:', 63, 'Jump:', 2)
# ('Idx:', 452, 'v_Surfing_g22_c02', 'Length:', 73, 'Jump:', 2)
# ('Idx:', 453, 'v_Kayaking_g19_c03', 'Length:', 178, 'Jump:', 2)
# ('Idx:', 454, 'v_IceDancing_g19_c01', 'Length:', 92, 'Jump:', 2)
# ('Idx:', 455, 'v_PlayingPiano_g01_c01', 'Length:', 215, 'Jump:', 2)
# ('Idx:', 456, 'v_Hammering_g13_c03', 'Length:', 105, 'Jump:', 2)
# ('Idx:', 457, 'v_PlayingGuitar_g13_c02', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 458, 'v_Kayaking_g04_c05', 'Length:', 188, 'Jump:', 2)
# ('Idx:', 459, 'v_WallPushups_g21_c01', 'Length:', 69, 'Jump:', 2)
# ('Idx:', 460, 'v_CleanAndJerk_g14_c03', 'Length:', 199, 'Jump:', 2)
# ('Idx:', 461, 'v_StillRings_g25_c04', 'Length:', 131, 'Jump:', 2)
# ('Idx:', 462, 'v_PushUps_g25_c03', 'Length:', 108, 'Jump:', 2)
# ('Idx:', 463, 'v_HighJump_g22_c02', 'Length:', 105, 'Jump:', 2)
# ('Idx:', 464, 'v_WallPushups_g14_c05', 'Length:', 112, 'Jump:', 2)
# ('Idx:', 465, 'v_ApplyEyeMakeup_g25_c06', 'Length:', 107, 'Jump:', 2)
# ('Idx:', 466, 'v_MilitaryParade_g19_c06', 'Length:', 135, 'Jump:', 2)
# ('Idx:', 467, 'v_CricketShot_g02_c06', 'Length:', 93, 'Jump:', 2)
# ('Idx:', 468, 'v_BabyCrawling_g07_c05', 'Length:', 139, 'Jump:', 2)
# ('Idx:', 469, 'v_WallPushups_g18_c02', 'Length:', 122, 'Jump:', 2)
# ('Idx:', 470, 'v_IceDancing_g06_c02', 'Length:', 246, 'Jump:', 2)
# ('Idx:', 471, 'v_PlayingDaf_g24_c02', 'Length:', 297, 'Jump:', 2)
# ('Idx:', 472, 'v_MilitaryParade_g07_c02', 'Length:', 141, 'Jump:', 2)
# ('Idx:', 473, 'v_Hammering_g03_c04', 'Length:', 128, 'Jump:', 2)
# ('Idx:', 474, 'v_ApplyEyeMakeup_g06_c04', 'Length:', 98, 'Jump:', 2)
# ('Idx:', 475, 'v_CricketShot_g06_c04', 'Length:', 132, 'Jump:', 2)
# ('Idx:', 476, 'v_Kayaking_g23_c05', 'Length:', 237, 'Jump:', 2)
# ('Idx:', 477, 'v_PlayingGuitar_g12_c07', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 478, 'v_HighJump_g25_c01', 'Length:', 93, 'Jump:', 2)
# ('Idx:', 479, 'v_PlayingGuitar_g06_c05', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 480, 'v_HighJump_g24_c01', 'Length:', 57, 'Jump:', 2)
# ('Idx:', 481, 'v_StillRings_g01_c04', 'Length:', 135, 'Jump:', 2)
# ('Idx:', 482, 'v_ApplyEyeMakeup_g24_c06', 'Length:', 220, 'Jump:', 2)
# ('Idx:', 483, 'v_PushUps_g15_c03', 'Length:', 82, 'Jump:', 2)
# ('Idx:', 484, 'v_MilitaryParade_g10_c05', 'Length:', 99, 'Jump:', 2)
# ('Idx:', 485, 'v_PlayingDhol_g24_c04', 'Length:', 271, 'Jump:', 2)
# ('Idx:', 486, 'v_PlayingGuitar_g10_c06', 'Length:', 247, 'Jump:', 2)
# ('Idx:', 487, 'v_HighJump_g19_c02', 'Length:', 78, 'Jump:', 2)
# ('Idx:', 488, 'v_CricketShot_g17_c04', 'Length:', 87, 'Jump:', 2)
# ('Idx:', 489, 'v_Shotput_g23_c04', 'Length:', 76, 'Jump:', 2)
# ('Idx:', 490, 'v_PushUps_g15_c04', 'Length:', 87, 'Jump:', 2)
# ('Idx:', 491, 'v_CricketShot_g07_c04', 'Length:', 115, 'Jump:', 2)
# ('Idx:', 492, 'v_Surfing_g08_c05', 'Length:', 264, 'Jump:', 2)
# ('Idx:', 493, 'v_CricketShot_g16_c06', 'Length:', 54, 'Jump:', 2)
# ('Idx:', 494, 'v_PushUps_g11_c02', 'Length:', 56, 'Jump:', 2)
# ('Idx:', 495, 'v_BrushingTeeth_g12_c03', 'Length:', 262, 'Jump:', 2)
# ('Idx:', 496, 'v_Shotput_g22_c05', 'Length:', 67, 'Jump:', 2)
# ('Idx:', 497, 'v_Shotput_g10_c03', 'Length:', 69, 'Jump:', 2)
# ('Idx:', 498, 'v_Shotput_g20_c03', 'Length:', 83, 'Jump:', 2)
# ('Idx:', 499, 'v_StillRings_g04_c01', 'Length:', 110, 'Jump:', 2)

# %%
inqs = get_inquiry(data, if_random = True)
seqY = inqs[1]

inq_result = inquiry_in_database(seqY, database)

# %%
print("Inqury is:\t"+ inqs[2])
print("Inqury frames:\t"+ str(inqs[3]))
print("Best Match is:\t"+ inq_result[3])
print("Best Dist:\t"+ str(inq_result[0]))

acc = inq_result[1]
path = inq_result[2]
imshow(acc.T, origin='lower', cmap=cm.gray, interpolation='nearest')
plot(path[0], path[1], 'w')
# xlim((-0.5, acc.shape[0]-0.5))
# ylim((-0.5, acc.shape[1]-0.5))

print("========================")
print("All scores in database:")
for i in range(len(inq_result[4])):
    print("Record: "+ inq_result[4][i][1].ljust(25)+ "\tDTW Dist: "+ str(inq_result[4][i][0]))
# Out:
# Inqury is:	v_Surfing_g05_c04
# Inqury frames:	[(0, 3), (28, 31), (56, 59), (84, 87), (112, 115), (140, 143), (168, 171), (196, 199)]
# Best Match is:	v_Surfing_g05_c04
# Best Dist:	1219.97432312
# ========================
# All scores in database:
# Record: v_Surfing_g05_c04        	DTW Dist: 1219.97432312
# Record: v_Surfing_g05_c02        	DTW Dist: 1493.28540433
# Record: v_Surfing_g04_c01        	DTW Dist: 1844.18065825
# Record: v_Surfing_g05_c01        	DTW Dist: 2046.99507812
# Record: v_Hammering_g16_c02      	DTW Dist: 2096.70188599
# Record: v_CleanAndJerk_g17_c03   	DTW Dist: 2105.39650365
# Record: v_Surfing_g22_c02        	DTW Dist: 2107.5023763
# Record: v_Hammering_g16_c01      	DTW Dist: 2153.88682593
# Record: v_WallPushups_g05_c05    	DTW Dist: 2205.49394956
# Record: v_WallPushups_g04_c01    	DTW Dist: 2211.42927078
# Record: v_PushUps_g16_c03        	DTW Dist: 2232.02715268
# Record: v_Surfing_g10_c03        	DTW Dist: 2258.7411656
# Record: v_Kayaking_g01_c05       	DTW Dist: 2259.27421099
# Record: v_Surfing_g03_c04        	DTW Dist: 2264.45413455
# Record: v_MilitaryParade_g10_c02 	DTW Dist: 2294.72130927
# Record: v_CricketShot_g13_c01    	DTW Dist: 2339.50537872
# Record: v_CleanAndJerk_g12_c02   	DTW Dist: 2340.890141
# Record: v_PushUps_g24_c04        	DTW Dist: 2347.75670224
# Record: v_HighJump_g08_c03       	DTW Dist: 2368.85046387
# Record: v_WallPushups_g14_c05    	DTW Dist: 2374.0709343
# Record: v_BabyCrawling_g14_c01   	DTW Dist: 2383.0616132
# Record: v_Shotput_g25_c03        	DTW Dist: 2387.8393457
# Record: v_BabyCrawling_g14_c02   	DTW Dist: 2399.4571153
# Record: v_WallPushups_g14_c02    	DTW Dist: 2402.32478516
# Record: v_ApplyEyeMakeup_g05_c06 	DTW Dist: 2419.7062162
# Record: v_HighJump_g02_c03       	DTW Dist: 2419.9694642
# Record: v_BabyCrawling_g14_c03   	DTW Dist: 2422.36993472
# Record: v_BlowDryHair_g04_c05    	DTW Dist: 2429.3844734
# Record: v_ApplyEyeMakeup_g05_c05 	DTW Dist: 2433.99211688
# Record: v_WallPushups_g25_c03    	DTW Dist: 2450.95000179
# Record: v_WallPushups_g25_c04    	DTW Dist: 2453.83852182
# Record: v_PlayingDaf_g06_c07     	DTW Dist: 2467.00736387
# Record: v_ApplyEyeMakeup_g11_c01 	DTW Dist: 2486.7017743
# Record: v_Shotput_g25_c05        	DTW Dist: 2496.12336077
# Record: v_HighJump_g23_c04       	DTW Dist: 2511.31385523
# Record: v_CricketShot_g05_c07    	DTW Dist: 2548.04383545
# Record: v_BrushingTeeth_g04_c04  	DTW Dist: 2557.92637862
# Record: v_BabyCrawling_g14_c04   	DTW Dist: 2561.07212286
# Record: v_Hammering_g10_c02      	DTW Dist: 2563.00133464
# Record: v_CricketShot_g23_c02    	DTW Dist: 2563.12819866
# Record: v_Shotput_g03_c05        	DTW Dist: 2577.97224731
# Record: v_BlowDryHair_g10_c07    	DTW Dist: 2578.4508455
# Record: v_BlowDryHair_g10_c05    	DTW Dist: 2581.62934082
# Record: v_Surfing_g07_c03        	DTW Dist: 2584.8691383
# Record: v_CricketShot_g05_c02    	DTW Dist: 2591.01935597
# Record: v_BlowDryHair_g24_c02    	DTW Dist: 2593.69292092
# Record: v_Hammering_g22_c05      	DTW Dist: 2608.91513062
# Record: v_Hammering_g22_c06      	DTW Dist: 2620.1783462
# Record: v_ApplyEyeMakeup_g05_c02 	DTW Dist: 2623.29685744
# Record: v_WallPushups_g19_c05    	DTW Dist: 2628.61496185
# Record: v_Shotput_g23_c04        	DTW Dist: 2629.39945652
# Record: v_BlowDryHair_g07_c07    	DTW Dist: 2635.83896684
# Record: v_Surfing_g15_c03        	DTW Dist: 2635.90967197
# Record: v_Shotput_g13_c04        	DTW Dist: 2639.62296365
# Record: v_WallPushups_g08_c04    	DTW Dist: 2642.41853243
# Record: v_ApplyEyeMakeup_g09_c05 	DTW Dist: 2651.02886024
# Record: v_Hammering_g22_c07      	DTW Dist: 2657.86040243
# Record: v_MilitaryParade_g11_c04 	DTW Dist: 2659.08720847
# Record: v_Surfing_g07_c02        	DTW Dist: 2683.65436416
# Record: v_Shotput_g06_c02        	DTW Dist: 2684.58744865
# Record: v_CleanAndJerk_g15_c02   	DTW Dist: 2688.50601196
# Record: v_MilitaryParade_g11_c01 	DTW Dist: 2691.97357768
# Record: v_HighJump_g02_c07       	DTW Dist: 2695.85216769
# Record: v_CricketShot_g16_c07    	DTW Dist: 2705.23532104
# Record: v_Hammering_g10_c01      	DTW Dist: 2705.39728461
# Record: v_BabyCrawling_g11_c03   	DTW Dist: 2706.04062586
# Record: v_Shotput_g04_c02        	DTW Dist: 2710.12296549
# Record: v_Shotput_g06_c07        	DTW Dist: 2719.93263402
# Record: v_CricketShot_g16_c05    	DTW Dist: 2723.17073568
# Record: v_BlowDryHair_g05_c02    	DTW Dist: 2727.58547006
# Record: v_CricketShot_g16_c06    	DTW Dist: 2745.34272461
# Record: v_HighJump_g02_c02       	DTW Dist: 2749.96106445
# Record: v_Surfing_g08_c05        	DTW Dist: 2755.14450509
# Record: v_Surfing_g10_c06        	DTW Dist: 2763.36778244
# Record: v_PlayingGuitar_g25_c05  	DTW Dist: 2766.08278032
# Record: v_Surfing_g01_c03        	DTW Dist: 2771.68404447
# Record: v_BrushingTeeth_g12_c04  	DTW Dist: 2775.50457469
# Record: v_Shotput_g16_c04        	DTW Dist: 2781.02614524
# Record: v_CricketShot_g24_c01    	DTW Dist: 2794.03769648
# Record: v_PlayingDhol_g07_c04    	DTW Dist: 2800.66917488
# Record: v_BrushingTeeth_g12_c03  	DTW Dist: 2802.06310245
# Record: v_StillRings_g05_c01     	DTW Dist: 2804.60499512
# Record: v_BabyCrawling_g21_c02   	DTW Dist: 2805.73310991
# Record: v_Surfing_g08_c04        	DTW Dist: 2817.01534375
# Record: v_BrushingTeeth_g25_c05  	DTW Dist: 2817.17941874
# Record: v_CricketShot_g11_c04    	DTW Dist: 2817.4996582
# Record: v_Surfing_g02_c03        	DTW Dist: 2823.08805116
# Record: v_MilitaryParade_g12_c03 	DTW Dist: 2824.11091444
# Record: v_BabyCrawling_g21_c03   	DTW Dist: 2826.44727173
# Record: v_PlayingGuitar_g25_c06  	DTW Dist: 2830.80065548
# Record: v_Shotput_g21_c04        	DTW Dist: 2831.09389106
# Record: v_WallPushups_g11_c02    	DTW Dist: 2833.36273471
# Record: v_WallPushups_g06_c02    	DTW Dist: 2836.78789231
# Record: v_WallPushups_g17_c01    	DTW Dist: 2840.42484715
# Record: v_Surfing_g09_c05        	DTW Dist: 2846.11353268
# Record: v_BlowDryHair_g10_c04    	DTW Dist: 2846.96334086
# Record: v_CleanAndJerk_g01_c01   	DTW Dist: 2853.11854955
# Record: v_IceDancing_g19_c01     	DTW Dist: 2856.14771864
# Record: v_BabyCrawling_g21_c04   	DTW Dist: 2862.87277641
# Record: v_BrushingTeeth_g21_c03  	DTW Dist: 2875.37224563
# Record: v_PushUps_g03_c02        	DTW Dist: 2878.63056384
# Record: v_BabyCrawling_g19_c04   	DTW Dist: 2880.44434212
# Record: v_CricketShot_g11_c06    	DTW Dist: 2888.30992226
# Record: v_CricketShot_g17_c04    	DTW Dist: 2895.23124343
# Record: v_Hammering_g06_c01      	DTW Dist: 2900.42553711
# Record: v_BlowDryHair_g22_c02    	DTW Dist: 2902.7193232
# Record: v_Shotput_g22_c05        	DTW Dist: 2904.85014997
# Record: v_MilitaryParade_g14_c04 	DTW Dist: 2904.89584961
# Record: v_Surfing_g15_c02        	DTW Dist: 2906.24154386
# Record: v_ApplyEyeMakeup_g20_c02 	DTW Dist: 2907.0889268
# Record: v_ApplyEyeMakeup_g24_c06 	DTW Dist: 2913.7348757
# Record: v_BlowDryHair_g04_c02    	DTW Dist: 2915.33088157
# Record: v_WallPushups_g18_c03    	DTW Dist: 2919.49939586
# Record: v_CleanAndJerk_g15_c03   	DTW Dist: 2926.81577532
# Record: v_PlayingGuitar_g07_c01  	DTW Dist: 2929.07458681
# Record: v_BlowDryHair_g23_c03    	DTW Dist: 2930.50769761
# Record: v_Shotput_g09_c02        	DTW Dist: 2938.64962981
# Record: v_ApplyEyeMakeup_g24_c04 	DTW Dist: 2954.65571993
# Record: v_WallPushups_g17_c05    	DTW Dist: 2957.01738657
# Record: v_BabyCrawling_g07_c03   	DTW Dist: 2958.32678354
# Record: v_Shotput_g15_c06        	DTW Dist: 2964.26414185
# Record: v_Shotput_g01_c04        	DTW Dist: 2969.2135908
# Record: v_BlowDryHair_g15_c01    	DTW Dist: 2972.39748757
# Record: v_WallPushups_g18_c02    	DTW Dist: 2974.01126585
# Record: v_PushUps_g15_c03        	DTW Dist: 2990.59939015
# Record: v_Kayaking_g06_c01       	DTW Dist: 2990.72078054
# Record: v_BabyCrawling_g07_c01   	DTW Dist: 2991.85003494
# Record: v_Kayaking_g06_c04       	DTW Dist: 2999.13494001
# Record: v_Shotput_g10_c03        	DTW Dist: 3000.56734307
# Record: v_CricketShot_g14_c04    	DTW Dist: 3010.06923503
# Record: v_Shotput_g20_c03        	DTW Dist: 3014.48359375
# Record: v_PlayingDaf_g16_c01     	DTW Dist: 3019.12353164
# Record: v_Shotput_g04_c03        	DTW Dist: 3022.24626465
# Record: v_WallPushups_g11_c03    	DTW Dist: 3023.60000888
# Record: v_IceDancing_g10_c06     	DTW Dist: 3025.84149625
# Record: v_ApplyEyeMakeup_g19_c04 	DTW Dist: 3030.3293156
# Record: v_Shotput_g01_c07        	DTW Dist: 3041.6962596
# Record: v_IceDancing_g10_c02     	DTW Dist: 3050.87894011
# Record: v_PushUps_g15_c04        	DTW Dist: 3059.33844464
# Record: v_ApplyEyeMakeup_g19_c03 	DTW Dist: 3060.80868094
# Record: v_BlowDryHair_g25_c04    	DTW Dist: 3064.22825405
# Record: v_WallPushups_g11_c05    	DTW Dist: 3081.99089392
# Record: v_IceDancing_g25_c04     	DTW Dist: 3085.41467111
# Record: v_ApplyEyeMakeup_g24_c01 	DTW Dist: 3087.88981718
# Record: v_PlayingDaf_g24_c02     	DTW Dist: 3089.88391658
# Record: v_CricketShot_g19_c04    	DTW Dist: 3090.14521883
# Record: v_Surfing_g06_c04        	DTW Dist: 3090.16168451
# Record: v_HighJump_g16_c01       	DTW Dist: 3094.64336689
# Record: v_CricketShot_g19_c03    	DTW Dist: 3095.41900245
# Record: v_BlowDryHair_g20_c01    	DTW Dist: 3097.09743482
# Record: v_Surfing_g06_c01        	DTW Dist: 3098.29872977
# Record: v_Shotput_g15_c01        	DTW Dist: 3099.24935303
# Record: v_MilitaryParade_g10_c04 	DTW Dist: 3101.13748468
# Record: v_PushUps_g18_c04        	DTW Dist: 3101.3228876
# Record: v_BabyCrawling_g19_c03   	DTW Dist: 3110.25725687
# Record: v_WallPushups_g24_c02    	DTW Dist: 3111.41296794
# Record: v_Surfing_g02_c06        	DTW Dist: 3120.08594252
# Record: v_BlowDryHair_g15_c02    	DTW Dist: 3123.52641369
# Record: v_IceDancing_g12_c02     	DTW Dist: 3141.04130566
# Record: v_Surfing_g13_c03        	DTW Dist: 3143.9022035
# Record: v_Shotput_g20_c01        	DTW Dist: 3145.95409012
# Record: v_HighJump_g12_c03       	DTW Dist: 3150.6501557
# Record: v_BlowDryHair_g17_c02    	DTW Dist: 3151.78572346
# Record: v_Hammering_g05_c04      	DTW Dist: 3152.36296498
# Record: v_Shotput_g07_c01        	DTW Dist: 3153.28455651
# Record: v_Shotput_g05_c06        	DTW Dist: 3154.2052281
# Record: v_PushUps_g25_c03        	DTW Dist: 3164.593687
# Record: v_ApplyEyeMakeup_g08_c05 	DTW Dist: 3169.77429115
# Record: v_CleanAndJerk_g05_c04   	DTW Dist: 3172.30925293
# Record: v_WallPushups_g15_c02    	DTW Dist: 3176.34182257
# Record: v_IceDancing_g23_c01     	DTW Dist: 3179.01790854
# Record: v_CricketShot_g02_c06    	DTW Dist: 3181.29717241
# Record: v_WallPushups_g15_c01    	DTW Dist: 3185.98035831
# Record: v_BrushingTeeth_g06_c02  	DTW Dist: 3190.08444843
# Record: v_Kayaking_g17_c01       	DTW Dist: 3193.54781132
# Record: v_BrushingTeeth_g22_c06  	DTW Dist: 3195.90289862
# Record: v_Kayaking_g10_c05       	DTW Dist: 3196.16485726
# Record: v_Surfing_g09_c02        	DTW Dist: 3202.48158637
# Record: v_MilitaryParade_g10_c05 	DTW Dist: 3205.50132173
# Record: v_WallPushups_g21_c01    	DTW Dist: 3206.58421148
# Record: v_CricketShot_g10_c03    	DTW Dist: 3211.44580646
# Record: v_BlowDryHair_g19_c01    	DTW Dist: 3213.93122337
# Record: v_PlayingDaf_g07_c01     	DTW Dist: 3217.85623658
# Record: v_CleanAndJerk_g02_c04   	DTW Dist: 3219.8406767
# Record: v_BrushingTeeth_g07_c05  	DTW Dist: 3221.12648162
# Record: v_CricketShot_g21_c04    	DTW Dist: 3223.15386091
# Record: v_IceDancing_g06_c02     	DTW Dist: 3225.56626088
# Record: v_IceDancing_g17_c05     	DTW Dist: 3232.51546349
# Record: v_Shotput_g01_c05        	DTW Dist: 3232.93612235
# Record: v_PushUps_g18_c02        	DTW Dist: 3235.54259091
# Record: v_BrushingTeeth_g22_c04  	DTW Dist: 3236.94266357
# Record: v_BlowDryHair_g16_c01    	DTW Dist: 3241.30095881
# Record: v_Surfing_g12_c06        	DTW Dist: 3243.00695935
# Record: v_Shotput_g07_c06        	DTW Dist: 3255.5205408
# Record: v_CricketShot_g10_c02    	DTW Dist: 3256.3520159
# Record: v_BrushingTeeth_g23_c03  	DTW Dist: 3266.45921758
# Record: v_IceDancing_g22_c01     	DTW Dist: 3270.82885742
# Record: v_HighJump_g24_c01       	DTW Dist: 3273.05332823
# Record: v_Surfing_g23_c01        	DTW Dist: 3275.1083056
# Record: v_HighJump_g25_c01       	DTW Dist: 3277.05822532
# Record: v_CricketShot_g07_c04    	DTW Dist: 3280.05126213
# Record: v_CleanAndJerk_g07_c04   	DTW Dist: 3281.49582503
# Record: v_BrushingTeeth_g04_c01  	DTW Dist: 3282.480848
# Record: v_CleanAndJerk_g07_c03   	DTW Dist: 3282.95327027
# Record: v_PlayingDhol_g11_c01    	DTW Dist: 3285.15065272
# Record: v_WallPushups_g20_c06    	DTW Dist: 3291.08259612
# Record: v_Hammering_g25_c04      	DTW Dist: 3292.380523
# Record: v_PlayingDhol_g08_c02    	DTW Dist: 3300.86507106
# Record: v_PushUps_g11_c03        	DTW Dist: 3317.15785846
# Record: v_Surfing_g12_c07        	DTW Dist: 3317.89995989
# Record: v_PushUps_g01_c02        	DTW Dist: 3320.00449811
# Record: v_PlayingDaf_g03_c01     	DTW Dist: 3323.88391113
# Record: v_IceDancing_g14_c03     	DTW Dist: 3324.04855483
# Record: v_ApplyEyeMakeup_g14_c03 	DTW Dist: 3330.20019919
# Record: v_IceDancing_g20_c06     	DTW Dist: 3332.83147347
# Record: v_CricketShot_g06_c05    	DTW Dist: 3335.0500237
# Record: v_ApplyEyeMakeup_g07_c03 	DTW Dist: 3335.05527806
# Record: v_ApplyEyeMakeup_g07_c04 	DTW Dist: 3336.77175982
# Record: v_BabyCrawling_g20_c03   	DTW Dist: 3340.7307972
# Record: v_WallPushups_g20_c04    	DTW Dist: 3341.6689239
# Record: v_BabyCrawling_g09_c04   	DTW Dist: 3349.09271573
# Record: v_PlayingDhol_g11_c03    	DTW Dist: 3349.25760091
# Record: v_IceDancing_g02_c05     	DTW Dist: 3350.08070456
# Record: v_PlayingDaf_g11_c03     	DTW Dist: 3350.5698758
# Record: v_CricketShot_g12_c01    	DTW Dist: 3351.60408401
# Record: v_WallPushups_g13_c02    	DTW Dist: 3353.833811
# Record: v_Shotput_g08_c04        	DTW Dist: 3354.05092425
# Record: v_PushUps_g11_c02        	DTW Dist: 3357.5968967
# Record: v_CricketShot_g10_c01    	DTW Dist: 3361.12237258
# Record: v_PlayingDaf_g07_c05     	DTW Dist: 3364.1220349
# Record: v_PlayingPiano_g14_c03   	DTW Dist: 3368.36238827
# Record: v_BlowDryHair_g02_c02    	DTW Dist: 3373.58726421
# Record: v_BlowDryHair_g16_c04    	DTW Dist: 3376.60586958
# Record: v_BlowDryHair_g22_c01    	DTW Dist: 3382.28127953
# Record: v_HighJump_g05_c02       	DTW Dist: 3390.33604794
# Record: v_HighJump_g19_c02       	DTW Dist: 3390.84599402
# Record: v_HighJump_g10_c02       	DTW Dist: 3413.49228516
# Record: v_Surfing_g16_c07        	DTW Dist: 3413.76981055
# Record: v_CleanAndJerk_g19_c03   	DTW Dist: 3418.5664274
# Record: v_Shotput_g24_c01        	DTW Dist: 3418.85097577
# Record: v_CricketShot_g10_c07    	DTW Dist: 3418.85676149
# Record: v_Surfing_g18_c01        	DTW Dist: 3420.5824428
# Record: v_PushUps_g12_c03        	DTW Dist: 3421.16310338
# Record: v_Surfing_g23_c02        	DTW Dist: 3432.24326509
# Record: v_PushUps_g12_c04        	DTW Dist: 3443.69210461
# Record: v_PlayingGuitar_g10_c02  	DTW Dist: 3444.42982807
# Record: v_Hammering_g08_c03      	DTW Dist: 3451.19922296
# Record: v_WallPushups_g22_c04    	DTW Dist: 3452.73740932
# Record: v_PlayingGuitar_g10_c06  	DTW Dist: 3460.42684844
# Record: v_Hammering_g02_c01      	DTW Dist: 3465.49081698
# Record: v_BabyCrawling_g20_c02   	DTW Dist: 3465.79018593
# Record: v_PlayingGuitar_g10_c07  	DTW Dist: 3473.37436745
# Record: v_ApplyEyeMakeup_g16_c04 	DTW Dist: 3474.36461966
# Record: v_CricketShot_g22_c05    	DTW Dist: 3477.7069889
# Record: v_ApplyEyeMakeup_g07_c06 	DTW Dist: 3478.67904386
# Record: v_CricketShot_g22_c03    	DTW Dist: 3480.12545989
# Record: v_ApplyEyeMakeup_g07_c02 	DTW Dist: 3480.57109321
# Record: v_ApplyEyeMakeup_g03_c06 	DTW Dist: 3485.26880177
# Record: v_IceDancing_g11_c01     	DTW Dist: 3485.63253348
# Record: v_IceDancing_g25_c05     	DTW Dist: 3490.0938608
# Record: v_Kayaking_g06_c06       	DTW Dist: 3493.76905981
# Record: v_BlowDryHair_g06_c07    	DTW Dist: 3499.09760471
# Record: v_MilitaryParade_g19_c06 	DTW Dist: 3507.11157869
# Record: v_ApplyEyeMakeup_g22_c01 	DTW Dist: 3522.7233701
# Record: v_CricketShot_g06_c04    	DTW Dist: 3523.19940021
# Record: v_WallPushups_g21_c03    	DTW Dist: 3524.63236292
# Record: v_Kayaking_g19_c03       	DTW Dist: 3527.61586612
# Record: v_ApplyEyeMakeup_g10_c02 	DTW Dist: 3530.06988961
# Record: v_Kayaking_g19_c01       	DTW Dist: 3531.18969503
# Record: v_PushUps_g11_c01        	DTW Dist: 3542.45761719
# Record: v_CleanAndJerk_g06_c02   	DTW Dist: 3543.92218722
# Record: v_HighJump_g06_c02       	DTW Dist: 3547.21838881
# Record: v_MilitaryParade_g09_c04 	DTW Dist: 3550.6703936
# Record: v_BabyCrawling_g02_c03   	DTW Dist: 3559.14957682
# Record: v_PushUps_g05_c04        	DTW Dist: 3560.46211652
# Record: v_ApplyEyeMakeup_g19_c02 	DTW Dist: 3564.14512741
# Record: v_PlayingGuitar_g12_c05  	DTW Dist: 3574.40826046
# Record: v_Hammering_g14_c01      	DTW Dist: 3575.40920928
# Record: v_PlayingGuitar_g12_c07  	DTW Dist: 3576.17664684
# Record: v_BabyCrawling_g17_c04   	DTW Dist: 3577.47613136
# Record: v_HighJump_g15_c03       	DTW Dist: 3579.68979061
# Record: v_HighJump_g22_c05       	DTW Dist: 3581.56107585
# Record: v_IceDancing_g12_c07     	DTW Dist: 3581.89030252
# Record: v_IceDancing_g09_c04     	DTW Dist: 3582.00158781
# Record: v_BabyCrawling_g07_c05   	DTW Dist: 3584.50967485
# Record: v_BabyCrawling_g16_c06   	DTW Dist: 3586.68856426
# Record: v_Hammering_g05_c01      	DTW Dist: 3592.5465195
# Record: v_PlayingGuitar_g04_c04  	DTW Dist: 3594.2156705
# Record: v_PlayingGuitar_g06_c06  	DTW Dist: 3606.90299479
# Record: v_PlayingGuitar_g06_c05  	DTW Dist: 3607.21715939
# Record: v_PlayingGuitar_g06_c01  	DTW Dist: 3608.51635002
# Record: v_Kayaking_g15_c01       	DTW Dist: 3613.88858958
# Record: v_PlayingDhol_g09_c01    	DTW Dist: 3615.78501796
# Record: v_IceDancing_g06_c04     	DTW Dist: 3616.95854828
# Record: v_PlayingDhol_g23_c04    	DTW Dist: 3619.25409739
# Record: v_Surfing_g14_c02        	DTW Dist: 3623.48117429
# Record: v_ApplyEyeMakeup_g10_c05 	DTW Dist: 3624.31777271
# Record: v_BlowDryHair_g14_c03    	DTW Dist: 3624.34715876
# Record: v_HighJump_g03_c02       	DTW Dist: 3627.8712094
# Record: v_PlayingDhol_g21_c04    	DTW Dist: 3628.66919824
# Record: v_IceDancing_g12_c01     	DTW Dist: 3634.47417492
# Record: v_Hammering_g12_c02      	DTW Dist: 3635.07724418
# Record: v_Hammering_g14_c04      	DTW Dist: 3638.70259126
# Record: v_Hammering_g17_c06      	DTW Dist: 3638.72841448
# Record: v_PlayingDhol_g23_c05    	DTW Dist: 3641.8975865
# Record: v_Surfing_g10_c01        	DTW Dist: 3644.24629815
# Record: v_MilitaryParade_g24_c04 	DTW Dist: 3649.63944092
# Record: v_IceDancing_g05_c06     	DTW Dist: 3650.06209946
# Record: v_Kayaking_g03_c04       	DTW Dist: 3657.0155249
# Record: v_Kayaking_g18_c03       	DTW Dist: 3657.84036458
# Record: v_ApplyEyeMakeup_g15_c04 	DTW Dist: 3657.88098507
# Record: v_PlayingDhol_g01_c06    	DTW Dist: 3662.78465388
# Record: v_IceDancing_g02_c01     	DTW Dist: 3666.69337023
# Record: v_CleanAndJerk_g11_c04   	DTW Dist: 3667.08124556
# Record: v_PushUps_g10_c01        	DTW Dist: 3673.26260004
# Record: v_BrushingTeeth_g14_c04  	DTW Dist: 3676.63477563
# Record: v_StillRings_g12_c02     	DTW Dist: 3678.95197251
# Record: v_CleanAndJerk_g08_c01   	DTW Dist: 3679.00858984
# Record: v_BabyCrawling_g25_c02   	DTW Dist: 3684.61833467
# Record: v_WallPushups_g02_c01    	DTW Dist: 3684.80582682
# Record: v_CricketShot_g04_c02    	DTW Dist: 3689.11948993
# Record: v_IceDancing_g16_c05     	DTW Dist: 3691.02039909
# Record: v_PlayingGuitar_g03_c04  	DTW Dist: 3695.88717004
# Record: v_Surfing_g18_c04        	DTW Dist: 3697.02442499
# Record: v_ApplyEyeMakeup_g16_c05 	DTW Dist: 3702.37610994
# Record: v_BabyCrawling_g25_c06   	DTW Dist: 3703.70112715
# Record: v_CleanAndJerk_g10_c04   	DTW Dist: 3704.17476014
# Record: v_Hammering_g17_c01      	DTW Dist: 3706.09726027
# Record: v_IceDancing_g11_c04     	DTW Dist: 3707.01576968
# Record: v_ApplyEyeMakeup_g22_c04 	DTW Dist: 3709.74808866
# Record: v_PlayingDaf_g10_c03     	DTW Dist: 3715.20278609
# Record: v_MilitaryParade_g09_c06 	DTW Dist: 3718.18329352
# Record: v_IceDancing_g03_c05     	DTW Dist: 3722.37462717
# Record: v_IceDancing_g17_c01     	DTW Dist: 3723.14572144
# Record: v_BrushingTeeth_g11_c03  	DTW Dist: 3726.45039139
# Record: v_CricketShot_g03_c05    	DTW Dist: 3731.48422189
# Record: v_MilitaryParade_g16_c01 	DTW Dist: 3733.10935756
# Record: v_BabyCrawling_g03_c02   	DTW Dist: 3735.61340206
# Record: v_Kayaking_g07_c03       	DTW Dist: 3735.64308912
# Record: v_Hammering_g12_c04      	DTW Dist: 3737.60026042
# Record: v_PlayingDhol_g18_c04    	DTW Dist: 3741.35423061
# Record: v_IceDancing_g21_c06     	DTW Dist: 3741.48123816
# Record: v_PushUps_g02_c03        	DTW Dist: 3744.6397652
# Record: v_PlayingDhol_g18_c03    	DTW Dist: 3744.78023198
# Record: v_ApplyEyeMakeup_g15_c03 	DTW Dist: 3753.79339351
# Record: v_MilitaryParade_g20_c02 	DTW Dist: 3753.85725812
# Record: v_BabyCrawling_g02_c06   	DTW Dist: 3758.21843884
# Record: v_IceDancing_g01_c04     	DTW Dist: 3762.62715059
# Record: v_Kayaking_g02_c03       	DTW Dist: 3765.09014326
# Record: v_HighJump_g07_c03       	DTW Dist: 3767.66834932
# Record: v_BabyCrawling_g15_c04   	DTW Dist: 3784.55941678
# Record: v_PushUps_g14_c01        	DTW Dist: 3784.62241548
# Record: v_BabyCrawling_g17_c05   	DTW Dist: 3787.4066359
# Record: v_PlayingPiano_g15_c02   	DTW Dist: 3793.52967093
# Record: v_Hammering_g13_c03      	DTW Dist: 3795.8161421
# Record: v_BlowDryHair_g03_c02    	DTW Dist: 3795.97583389
# Record: v_Kayaking_g03_c03       	DTW Dist: 3797.81992964
# Record: v_IceDancing_g07_c06     	DTW Dist: 3802.42974356
# Record: v_PlayingGuitar_g24_c02  	DTW Dist: 3803.68223618
# Record: v_Surfing_g11_c04        	DTW Dist: 3806.51622264
# Record: v_CleanAndJerk_g14_c03   	DTW Dist: 3807.20717593
# Record: v_ApplyEyeMakeup_g23_c04 	DTW Dist: 3807.69034755
# Record: v_BrushingTeeth_g08_c01  	DTW Dist: 3809.17407735
# Record: v_HighJump_g17_c01       	DTW Dist: 3809.20359349
# Record: v_Surfing_g25_c01        	DTW Dist: 3811.50997433
# Record: v_MilitaryParade_g05_c02 	DTW Dist: 3812.44513924
# Record: v_StillRings_g20_c04     	DTW Dist: 3818.48557692
# Record: v_Kayaking_g04_c01       	DTW Dist: 3818.60984349
# Record: v_HighJump_g22_c02       	DTW Dist: 3820.89808129
# Record: v_IceDancing_g24_c06     	DTW Dist: 3821.960237
# Record: v_BabyCrawling_g16_c04   	DTW Dist: 3825.30135311
# Record: v_MilitaryParade_g19_c03 	DTW Dist: 3827.18827427
# Record: v_BabyCrawling_g24_c06   	DTW Dist: 3828.75184993
# Record: v_IceDancing_g05_c01     	DTW Dist: 3829.57766467
# Record: v_ApplyEyeMakeup_g06_c04 	DTW Dist: 3835.39370032
# Record: v_BrushingTeeth_g17_c05  	DTW Dist: 3840.05204795
# Record: v_HighJump_g22_c01       	DTW Dist: 3843.03659708
# Record: v_PlayingGuitar_g21_c05  	DTW Dist: 3843.37536251
# Record: v_IceDancing_g19_c06     	DTW Dist: 3855.78926259
# Record: v_PushUps_g01_c04        	DTW Dist: 3856.50599179
# Record: v_MilitaryParade_g25_c02 	DTW Dist: 3866.60687832
# Record: v_BrushingTeeth_g03_c01  	DTW Dist: 3867.7356899
# Record: v_PlayingDhol_g15_c01    	DTW Dist: 3871.31958008
# Record: v_StillRings_g06_c03     	DTW Dist: 3883.25103502
# Record: v_HighJump_g22_c03       	DTW Dist: 3887.87448257
# Record: v_PlayingGuitar_g08_c02  	DTW Dist: 3892.39341597
# Record: v_CleanAndJerk_g16_c04   	DTW Dist: 3897.06411133
# Record: v_IceDancing_g05_c03     	DTW Dist: 3897.69352341
# Record: v_Kayaking_g09_c06       	DTW Dist: 3897.78131495
# Record: v_PlayingDhol_g24_c01    	DTW Dist: 3902.80051967
# Record: v_PlayingDaf_g18_c07     	DTW Dist: 3903.14092172
# Record: v_WallPushups_g03_c04    	DTW Dist: 3906.64431237
# Record: v_Kayaking_g23_c01       	DTW Dist: 3917.77906558
# Record: v_BrushingTeeth_g17_c03  	DTW Dist: 3920.68125454
# Record: v_MilitaryParade_g04_c01 	DTW Dist: 3948.12700521
# Record: v_PlayingDaf_g18_c06     	DTW Dist: 3954.68213844
# Record: v_IceDancing_g15_c02     	DTW Dist: 3959.42911414
# Record: v_PlayingDhol_g05_c06    	DTW Dist: 3963.45312183
# Record: v_PlayingDhol_g24_c04    	DTW Dist: 3969.80715095
# Record: v_WallPushups_g03_c02    	DTW Dist: 3972.0982629
# Record: v_PushUps_g04_c04        	DTW Dist: 3990.49874539
# Record: v_MilitaryParade_g09_c02 	DTW Dist: 3995.63227395
# Record: v_StillRings_g02_c04     	DTW Dist: 3998.46292509
# Record: v_MilitaryParade_g25_c07 	DTW Dist: 4004.85913086
# Record: v_Kayaking_g20_c02       	DTW Dist: 4008.56246116
# Record: v_Kayaking_g09_c04       	DTW Dist: 4015.33682736
# Record: v_PlayingDhol_g19_c04    	DTW Dist: 4015.57947788
# Record: v_Hammering_g09_c03      	DTW Dist: 4022.01639441
# Record: v_MilitaryParade_g04_c03 	DTW Dist: 4024.37392519
# Record: v_StillRings_g15_c01     	DTW Dist: 4024.68429362
# Record: v_MilitaryParade_g02_c01 	DTW Dist: 4030.51212412
# Record: v_PlayingGuitar_g11_c06  	DTW Dist: 4033.67444403
# Record: v_PlayingPiano_g12_c01   	DTW Dist: 4035.1744192
# Record: v_IceDancing_g11_c03     	DTW Dist: 4039.86752893
# Record: v_Hammering_g09_c01      	DTW Dist: 4044.81488186
# Record: v_PlayingGuitar_g11_c03  	DTW Dist: 4047.97876162
# Record: v_Hammering_g23_c06      	DTW Dist: 4050.06650965
# Record: v_Kayaking_g02_c01       	DTW Dist: 4053.84390662
# Record: v_ApplyEyeMakeup_g06_c01 	DTW Dist: 4060.98220627
# Record: v_PlayingGuitar_g05_c05  	DTW Dist: 4073.26808216
# Record: v_IceDancing_g07_c04     	DTW Dist: 4074.90841325
# Record: v_PlayingDhol_g22_c03    	DTW Dist: 4081.45096995
# Record: v_PlayingGuitar_g11_c04  	DTW Dist: 4097.28928075
# Record: v_BrushingTeeth_g13_c03  	DTW Dist: 4101.23775368
# Record: v_MilitaryParade_g25_c03 	DTW Dist: 4103.76905672
# Record: v_IceDancing_g04_c07     	DTW Dist: 4125.11505036
# Record: v_Kayaking_g23_c05       	DTW Dist: 4126.19514718
# Record: v_StillRings_g01_c02     	DTW Dist: 4129.44196112
# Record: v_Kayaking_g04_c05       	DTW Dist: 4143.04140098
# Record: v_PlayingPiano_g01_c01   	DTW Dist: 4143.16759833
# Record: v_IceDancing_g08_c01     	DTW Dist: 4152.57250417
# Record: v_Hammering_g18_c01      	DTW Dist: 4165.17180798
# Record: v_ApplyEyeMakeup_g17_c04 	DTW Dist: 4167.06922201
# Record: v_MilitaryParade_g22_c03 	DTW Dist: 4175.29756986
# Record: v_IceDancing_g04_c04     	DTW Dist: 4177.96877219
# Record: v_PlayingDhol_g22_c05    	DTW Dist: 4179.96820706
# Record: v_Kayaking_g20_c04       	DTW Dist: 4185.11901855
# Record: v_CleanAndJerk_g13_c04   	DTW Dist: 4188.67442708
# Record: v_PlayingGuitar_g23_c06  	DTW Dist: 4192.01452637
# Record: v_PlayingDhol_g22_c06    	DTW Dist: 4201.00123892
# Record: v_PlayingGuitar_g13_c02  	DTW Dist: 4201.35646011
# Record: v_Hammering_g15_c07      	DTW Dist: 4202.74116785
# Record: v_IceDancing_g20_c04     	DTW Dist: 4203.44163929
# Record: v_ApplyEyeMakeup_g21_c04 	DTW Dist: 4206.33059465
# Record: v_ApplyEyeMakeup_g06_c05 	DTW Dist: 4206.35630015
# Record: v_Hammering_g03_c02      	DTW Dist: 4206.95096628
# Record: v_MilitaryParade_g17_c03 	DTW Dist: 4208.32208573
# Record: v_PlayingGuitar_g23_c02  	DTW Dist: 4219.7352036
# Record: v_Kayaking_g21_c03       	DTW Dist: 4229.78503271
# Record: v_CleanAndJerk_g04_c03   	DTW Dist: 4235.41173706
# Record: v_ApplyEyeMakeup_g17_c03 	DTW Dist: 4238.41436089
# Record: v_MilitaryParade_g03_c04 	DTW Dist: 4238.69818018
# Record: v_PlayingGuitar_g20_c07  	DTW Dist: 4246.29869126
# Record: v_StillRings_g05_c03     	DTW Dist: 4246.84950885
# Record: v_MilitaryParade_g15_c07 	DTW Dist: 4249.62821925
# Record: v_ApplyEyeMakeup_g21_c01 	DTW Dist: 4250.74610371
# Record: v_Kayaking_g08_c04       	DTW Dist: 4275.47065536
# Record: v_PlayingGuitar_g15_c02  	DTW Dist: 4287.55871212
# Record: v_PlayingGuitar_g18_c01  	DTW Dist: 4341.15125252
# Record: v_MilitaryParade_g18_c02 	DTW Dist: 4343.75418091
# Record: v_PlayingGuitar_g13_c06  	DTW Dist: 4357.96131111
# Record: v_Kayaking_g20_c05       	DTW Dist: 4362.62831809
# Record: v_Hammering_g18_c04      	DTW Dist: 4366.2470932
# Record: v_Hammering_g03_c04      	DTW Dist: 4374.18056234
# Record: v_ApplyEyeMakeup_g25_c06 	DTW Dist: 4397.8016318
# Record: v_IceDancing_g02_c02     	DTW Dist: 4408.12621887
# Record: v_PlayingPiano_g13_c02   	DTW Dist: 4419.51465272
# Record: v_HighJump_g21_c01       	DTW Dist: 4432.50159021
# Record: v_PlayingPiano_g06_c02   	DTW Dist: 4440.65500033
# Record: v_IceDancing_g23_c07     	DTW Dist: 4444.59056866
# Record: v_StillRings_g07_c02     	DTW Dist: 4457.26964472
# Record: v_Kayaking_g22_c02       	DTW Dist: 4461.74820796
# Record: v_PlayingDaf_g23_c01     	DTW Dist: 4504.6817942
# Record: v_BrushingTeeth_g10_c01  	DTW Dist: 4515.39806157
# Record: v_PlayingPiano_g05_c02   	DTW Dist: 4542.61420447
# Record: v_StillRings_g01_c04     	DTW Dist: 4546.68705027
# Record: v_ApplyEyeMakeup_g25_c03 	DTW Dist: 4548.29601004
# Record: v_PlayingPiano_g11_c02   	DTW Dist: 4548.53827058
# Record: v_BabyCrawling_g23_c04   	DTW Dist: 4563.58127618
# Record: v_StillRings_g22_c02     	DTW Dist: 4593.10074301
# Record: v_BrushingTeeth_g10_c03  	DTW Dist: 4594.90870449
# Record: v_StillRings_g25_c04     	DTW Dist: 4612.87730284
# Record: v_ApplyEyeMakeup_g25_c04 	DTW Dist: 4688.59271749
# Record: v_MilitaryParade_g24_c01 	DTW Dist: 4692.32112911
# Record: v_PlayingDaf_g14_c03     	DTW Dist: 4725.0414605
# Record: v_CleanAndJerk_g09_c01   	DTW Dist: 4768.00939115
# Record: v_PlayingDaf_g17_c04     	DTW Dist: 4769.91463039
# Record: v_MilitaryParade_g23_c02 	DTW Dist: 4789.52099609
# Record: v_StillRings_g24_c03     	DTW Dist: 4816.10149129
# Record: v_PlayingPiano_g07_c04   	DTW Dist: 4869.23351491
# Record: v_MilitaryParade_g07_c05 	DTW Dist: 4901.61721161
# Record: v_BabyCrawling_g12_c06   	DTW Dist: 4919.81484233
# Record: v_ApplyEyeMakeup_g18_c01 	DTW Dist: 4923.5015827
# Record: v_StillRings_g04_c01     	DTW Dist: 4939.10661582
# Record: v_MilitaryParade_g07_c02 	DTW Dist: 4997.03456908
# Record: v_PlayingPiano_g04_c03   	DTW Dist: 5089.08786823
# Record: v_PlayingPiano_g10_c03   	DTW Dist: 5118.42964504
# Record: v_PlayingPiano_g23_c01   	DTW Dist: 5161.7485602
# Record: v_PlayingPiano_g10_c04   	DTW Dist: 5165.47946347
# Record: v_PlayingPiano_g02_c04   	DTW Dist: 5350.96594238

# %%
def get_category(str):
    return str.split('_')[1]

# %%
def multiple_test(data,run_times=100, if_itself=True):
    # how top result will be counted
    Count_tops = 5
    
    Total_run = run_times
    # Tops_same: number of same category as inq appeared in result list
    Tops_same = [0.0] * Count_tops
    
    # Sum of Score of Nth element of return list
    Nth_score_sum = [0.0] * Count_tops
    Hit_itself_sum = [0.0] * Count_tops
    self_pos_sum = 0
    
    run_times = min(run_times, len(data.data)-N_database)

    if if_itself:
        stpos = 0
    else:
        stpos = N_database
#     print(stpos)
    
    for i in range(0, run_times):
        inqs = get_inquiry(data, if_random = False, pos= stpos+i)
        seqY = inqs[1]
        inq_result = inquiry_in_database(seqY, database)
        for j in range(0, Count_tops):
            if(get_category(inq_result[4][j][1]) == get_category(inqs[2])):
                for k in range(j, Count_tops):
                    Tops_same[k] += 1
#                 break
                
        for j in range(0, Count_tops):
            Nth_score_sum[j] += inq_result[4][j][0]
            if(inq_result[4][j][1] == inqs[2]):
                Hit_itself_sum[j] += 1
            
    top_cat_same = [x/Total_run for x in Tops_same]
    Nth_score_avg = [x/Total_run for x in Nth_score_sum]
    Hit_itself_avg = [x/Total_run for x in Hit_itself_sum]
    
    print(top_cat_same, Nth_score_avg, Hit_itself_avg)
    
    return (top_cat_same, Nth_score_avg, Hit_itself_avg)

# %%
multiple_test(data, run_times=2, if_itself=True)
# Out:
# ([1.0, 2.0, 2.5, 2.5, 3.0], [686.65270535153297, 2534.306706969222, 2672.1718872271858, 2791.8872916865157, 2806.7918457813753])
# ([1.0, 2.0, 2.5, 2.5, 3.0],
#  [686.65270535153297,
#   2534.306706969222,
#   2672.1718872271858,
#   2791.8872916865157,
#   2806.7918457813753])
